# %% [markdown]
# # SQL Generator
# A sample how to build translator from natural language to SQL:
#
# * GPT 35
# * Panel
# * OpenAI
#
# I'm using jupyter just to keep it simple
# feel free to use you favourite IDE like Pycharm or any other.

# %%
# !pip install openai
# !pip install panel
# Out:
# Requirement already satisfied: openai in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (0.27.8)
# Requirement already satisfied: requests>=2.20 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from openai) (2.28.1)
# Requirement already satisfied: tqdm in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from openai) (4.64.0)
# Requirement already satisfied: aiohttp in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from openai) (3.8.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from requests>=2.20->openai) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from requests>=2.20->openai) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from requests>=2.20->openai) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from requests>=2.20->openai) (2022.6.15)
# Requirement already satisfied: attrs>=17.3.0 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from aiohttp->openai) (21.4.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from aiohttp->openai) (6.0.4)
# Requirement already satisfied: async-timeout<5.0,>=4.0.0a3 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from aiohttp->openai) (4.0.2)
# Requirement already satisfied: yarl<2.0,>=1.0 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from aiohttp->openai) (1.8.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from aiohttp->openai) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from aiohttp->openai) (1.3.1)
#
# [notice] A new release of pip is available: 23.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip
# Requirement already satisfied: panel in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (1.1.0)
# Requirement already satisfied: bokeh<3.2.0,>=3.1.1 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from panel) (3.1.1)
# Requirement already satisfied: param>=1.12.0 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from panel) (1.13.0)
# Requirement already satisfied: pyviz-comms>=0.7.4 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from panel) (2.3.1)
# Requirement already satisfied: xyzservices>=2021.09.1 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from panel) (2023.5.0)
# Requirement already satisfied: markdown in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from panel) (3.3.6)
# Requirement already satisfied: markdown-it-py<3 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from panel) (2.2.0)
# Requirement already satisfied: linkify-it-py in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from panel) (2.0.2)
# Requirement already satisfied: mdit-py-plugins in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from panel) (0.4.0)
# Requirement already satisfied: requests in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from panel) (2.28.1)
# Requirement already satisfied: tqdm>=4.48.0 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from panel) (4.64.0)
# Requirement already satisfied: bleach in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from panel) (5.0.1)
# Requirement already satisfied: typing-extensions in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from panel) (4.3.0)
# Requirement already satisfied: pandas>=1.2 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from panel) (1.4.2)
# Requirement already satisfied: Jinja2>=2.9 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from bokeh<3.2.0,>=3.1.1->panel) (3.1.2)
# Requirement already satisfied: contourpy>=1 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from bokeh<3.2.0,>=3.1.1->panel) (1.0.7)
# Requirement already satisfied: numpy>=1.16 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from bokeh<3.2.0,>=3.1.1->panel) (1.22.4)
# Requirement already satisfied: packaging>=16.8 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from bokeh<3.2.0,>=3.1.1->panel) (21.3)
# Requirement already satisfied: pillow>=7.1.0 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from bokeh<3.2.0,>=3.1.1->panel) (9.1.1)
# Requirement already satisfied: PyYAML>=3.10 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from bokeh<3.2.0,>=3.1.1->panel) (6.0)
# Requirement already satisfied: tornado>=5.1 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from bokeh<3.2.0,>=3.1.1->panel) (6.2)
# Requirement already satisfied: mdurl~=0.1 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from markdown-it-py<3->panel) (0.1.2)
# Requirement already satisfied: python-dateutil>=2.8.1 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from pandas>=1.2->panel) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from pandas>=1.2->panel) (2022.1)
# Requirement already satisfied: six>=1.9.0 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from bleach->panel) (1.15.0)
# Requirement already satisfied: webencodings in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from bleach->panel) (0.5.1)
# Requirement already satisfied: uc-micro-py in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from linkify-it-py->panel) (1.0.2)
# Requirement already satisfied: importlib-metadata>=4.4 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from markdown->panel) (4.11.4)
# Requirement already satisfied: charset-normalizer<3,>=2 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from requests->panel) (2.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from requests->panel) (3.3)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from requests->panel) (1.26.11)
# Requirement already satisfied: certifi>=2017.4.17 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from requests->panel) (2022.6.15)
# Requirement already satisfied: zipp>=0.5 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from importlib-metadata>=4.4->markdown->panel) (3.8.0)
# Requirement already satisfied: MarkupSafe>=2.0 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from Jinja2>=2.9->bokeh<3.2.0,>=3.1.1->panel) (2.1.1)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /Users/pere/miniforge3/envs/tf0922/lib/python3.8/site-packages (from packaging>=16.8->bokeh<3.2.0,>=3.1.1->panel) (3.0.9)
#
# [notice] A new release of pip is available: 23.1 -> 23.1.2
# [notice] To update, run: pip install --upgrade pip

# %%
import openai 
import panel as pn
from mykeys import openai_api_key
openai.api_key=openai_api_key

# %%
def continue_conversation(messages, temperature=0):
    response = openai.ChatCompletion.create(
        model="gpt-3.5-turbo",
        messages=messages,
        temperature=temperature, 
    )
    #print(str(response.choices[0].message["content"]))
    return response.choices[0].message["content"]

# %%
def add_prompts_conversation(_):
    #Get the value introduced by the user
    prompt = client_prompt.value_input
    client_prompt.value = ''
    
    #Append to the context the User promnopt. 
    context.append({'role':'user', 'content':f"{prompt}."})
    context.append({'role':'system', 'content':f"Remember your instructions as SQL Assistant."})
    
    #Get the response. 
    response = continue_conversation(context) 
    
    #Add the response to the context. 
    context.append({'role':'assistant', 'content':f"{response}"})
    
    #Undate the panels to shjow the conversation. 
    panels.append(
        pn.Row('User:', pn.pane.Markdown(prompt, width=600)))
    panels.append(
        pn.Row('Assistant:', pn.pane.Markdown(response, width=600, styles={'background-color': '#F6F6F6'})))
 
    return pn.Column(*panels)

# %%
context = [ {'role':'system', 'content':"""
you are a boot to assist in create SQL commands, all your answers should start with \
this is your SQL, and after that an SQL that can do what the user request. \
Your Database is composed by a SQL database with some tables. \
Try to Mantain the SQL order simple.
Put the SQL command in white letters with a black background, and just after \
a simple and concise text explaining how it works. 
If the user ask for something that can not be solved with an SQL Order \
just answer something nice and simple and ask him for something that \
can be solved with SQL. 
"""} ]  

context.append( {'role':'system', 'content':"""
first table: 
{
  "tableName": "employees",
  "fields": [
    {
      "nombre": "ID_usr",
      "tipo": "int"
    },
    {
      "nombre": "name",
      "tipo": "string"
    }
  ]
}
"""
})

context.append( {'role':'system', 'content':"""
second table: 
{
  "tableName": "salary",
  "fields": [
    {
      "nombre": "ID_usr",
      "type": "int"
    },
    {
      "name": "year",
      "type": "date"
    },
    {
      "name": "salary",
      "type": "float"
    }
  ]
}
"""
})

context.append( {'role':'system', 'content':"""
third table: 
{
  "tablename": "studies",
  "fields": [
    {
      "name": "ID",
      "type": "int"
    },
    {
      "name": "ID_usr",
      "type": "int"
    },
    {
      "name": "educational level",
      "type": "int"
    },
    {
      "name": "Institution",
      "type": "string"
    },
    {
      "name": "Years",
      "type": "date"
    }
    {
      "name": "Speciality",
      "type": "string"
    }
  ]
}
"""
})

#Creamos el panel. 
pn.extension()

panels = [] 

client_prompt = pn.widgets.TextInput(value="Hi", placeholder='Order your data…')
button_conversation = pn.widgets.Button(name="generate SQL")

interactive_conversation = pn.bind(add_prompts_conversation, button_conversation)

dashboard = pn.Column(
    client_prompt,
    pn.Row(button_conversation),
    pn.panel(interactive_conversation, loading_indicator=True, height=300),
)
# Out:
# <style>*[data-root-id],
# *[data-root-id] > * {
#   box-sizing: border-box;
#   font-family: var(--jp-ui-font-family);
#   font-size: var(--jp-ui-font-size1);
#   color: var(--vscode-editor-foreground, var(--jp-ui-font-color1));
# }
#
# /* Override VSCode background color */
# .cell-output-ipywidget-background:has(> .cell-output-ipywidget-background
#     > .lm-Widget
#     > *[data-root-id]),
# .cell-output-ipywidget-background:has(> .lm-Widget > *[data-root-id]) {
#   background-color: transparent !important;
# }
# </style>
# <div id='2965417a-496d-476f-821e-5b3b0b63b8c7'>
#   <div id="fd4152a8-780a-4d42-b0fd-e413dd13d546" data-root-id="2965417a-496d-476f-821e-5b3b0b63b8c7" style="display: contents;"></div>
# </div>
# <script type="application/javascript">(function(root) {
#   var docs_json = {"5c58416e-a3cf-45f5-a67a-47282a665881":{"version":"3.1.1","title":"Bokeh Application","defs":[{"type":"model","name":"ReactiveHTML1"},{"type":"model","name":"FlexBox1","properties":[{"name":"align_content","kind":"Any","default":"flex-start"},{"name":"align_items","kind":"Any","default":"flex-start"},{"name":"flex_direction","kind":"Any","default":"row"},{"name":"flex_wrap","kind":"Any","default":"wrap"},{"name":"justify_content","kind":"Any","default":"flex-start"}]},{"type":"model","name":"FloatPanel1","properties":[{"name":"config","kind":"Any","default":{"type":"map"}},{"name":"contained","kind":"Any","default":true},{"name":"position","kind":"Any","default":"right-top"},{"name":"offsetx","kind":"Any","default":null},{"name":"offsety","kind":"Any","default":null},{"name":"theme","kind":"Any","default":"primary"},{"name":"status","kind":"Any","default":"normalized"}]},{"type":"model","name":"GridStack1","properties":[{"name":"mode","kind":"Any","default":"warn"},{"name":"ncols","kind":"Any","default":null},{"name":"nrows","kind":"Any","default":null},{"name":"allow_resize","kind":"Any","default":true},{"name":"allow_drag","kind":"Any","default":true},{"name":"state","kind":"Any","default":[]}]},{"type":"model","name":"drag1","properties":[{"name":"slider_width","kind":"Any","default":5},{"name":"slider_color","kind":"Any","default":"black"},{"name":"value","kind":"Any","default":50}]},{"type":"model","name":"click1","properties":[{"name":"terminal_output","kind":"Any","default":""},{"name":"debug_name","kind":"Any","default":""},{"name":"clears","kind":"Any","default":0}]},{"type":"model","name":"FastWrapper1","properties":[{"name":"object","kind":"Any","default":null},{"name":"style","kind":"Any","default":null}]},{"type":"model","name":"NotificationAreaBase1","properties":[{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0}]},{"type":"model","name":"NotificationArea1","properties":[{"name":"notifications","kind":"Any","default":[]},{"name":"position","kind":"Any","default":"bottom-right"},{"name":"_clear","kind":"Any","default":0},{"name":"types","kind":"Any","default":[{"type":"map","entries":[["type","warning"],["background","#ffc107"],["icon",{"type":"map","entries":[["className","fas fa-exclamation-triangle"],["tagName","i"],["color","white"]]}]]},{"type":"map","entries":[["type","info"],["background","#007bff"],["icon",{"type":"map","entries":[["className","fas fa-info-circle"],["tagName","i"],["color","white"]]}]]}]}]},{"type":"model","name":"Notification","properties":[{"name":"background","kind":"Any","default":null},{"name":"duration","kind":"Any","default":3000},{"name":"icon","kind":"Any","default":null},{"name":"message","kind":"Any","default":""},{"name":"notification_type","kind":"Any","default":null},{"name":"_destroyed","kind":"Any","default":false}]},{"type":"model","name":"TemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"BootstrapTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]},{"type":"model","name":"MaterialTemplateActions1","properties":[{"name":"open_modal","kind":"Any","default":0},{"name":"close_modal","kind":"Any","default":0}]}],"roots":[{"type":"object","name":"panel.models.browser.BrowserInfo","id":"2965417a-496d-476f-821e-5b3b0b63b8c7"},{"type":"object","name":"panel.models.comm_manager.CommManager","id":"2ca61e3e-3017-489a-b0e8-b2e41375f90e","attributes":{"plot_id":"2965417a-496d-476f-821e-5b3b0b63b8c7","comm_id":"bd346af53acb4759bf21d26e59817c32","client_comm_id":"1901bb340c8a46c69e51684fd28703e6"}}],"callbacks":{"type":"map"}}};
#   var render_items = [{"docid":"5c58416e-a3cf-45f5-a67a-47282a665881","roots":{"2965417a-496d-476f-821e-5b3b0b63b8c7":"fd4152a8-780a-4d42-b0fd-e413dd13d546"},"root_ids":["2965417a-496d-476f-821e-5b3b0b63b8c7"]}];
#   var docs = Object.values(docs_json)
#   if (!docs) {
#     return
#   }
#   const py_version = docs[0].version.replace('rc', '-rc.')
#   const is_dev = py_version.indexOf("+") !== -1 || py_version.indexOf("-") !== -1
#   function embed_document(root) {
#     var Bokeh = get_bokeh(root)
#     Bokeh.embed.embed_items_notebook(docs_json, render_items);
#     for (const render_item of render_items) {
#       for (const root_id of render_item.root_ids) {
# 	const id_el = document.getElementById(root_id)
# 	if (id_el.children.length && (id_el.children[0].className === 'bk-root')) {
# 	  const root_el = id_el.children[0]
# 	  root_el.id = root_el.id + '-rendered'
# 	}
#       }
#     }
#   }
#   function get_bokeh(root) {
#     if (root.Bokeh === undefined) {
#       return null
#     } else if (root.Bokeh.version !== py_version && !is_dev) {
#       if (root.Bokeh.versions === undefined || !root.Bokeh.versions.has(py_version)) {
# 	return null
#       }
#       return root.Bokeh.versions.get(py_version);
#     } else if (root.Bokeh.version === py_version) {
#       return root.Bokeh
#     }
#     return null
#   }
#   function is_loaded(root) {
#     var Bokeh = get_bokeh(root)
#     return (Bokeh != null && Bokeh.Panel !== undefined)
#   }
#   if (is_loaded(root)) {
#     embed_document(root);
#   } else {
#     var attempts = 0;
#     var timer = setInterval(function(root) {
#       if (is_loaded(root)) {
#         clearInterval(timer);
#         embed_document(root);
#       } else if (document.readyState == "complete") {
#         attempts++;
#         if (attempts > 200) {
#           clearInterval(timer);
# 	  var Bokeh = get_bokeh(root)
# 	  if (Bokeh == null || Bokeh.Panel == null) {
#             console.warn("Panel: ERROR: Unable to run Panel code because Bokeh or Panel library is missing");
# 	  } else {
# 	    console.warn("Panel: WARNING: Attempting to render but not all required libraries could be resolved.")
# 	    embed_document(root)
# 	  }
#         }
#       }
#     }, 25, root)
#   }
# })(window);</script>

# %%
dashboard
# Out:
# Column
#     [0] TextInput(placeholder='Order your data…')
#     [1] Row
#         [0] Button(name='generate SQL')
#     [2] ParamFunction(function, _pane=Column, height=300, loading_indicator=True)
