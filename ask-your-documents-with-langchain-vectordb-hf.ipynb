# %% [markdown]
# <a href="https://www.kaggle.com/code/peremartramanonellas/ask-your-documents-with-langchain-vectordb-hf?scriptVersionId=137659922" target="_blank"><img align="left" alt="Kaggle" title="Open in Kaggle" src="https://kaggle.com/static/images/open-in-kaggle.svg"></a>

# %%
from IPython.core.display import HTML
HTML("""
<style>
.output_png {
    display: table-cell;
    text-align: center;
    vertical-align: middle;
    horizontal-align: middle;
}
h1 {
    text-align: center;
    background-color: #6bacf5;
    padding: 10px;
    margin: 0;
    font-family: monospace;
    color:DimGray;
    border-radius: 2px
    style="font-family:verdana;"
}

h2 {
    text-align: center;
    background-color: #83c2ff;
    padding: 10px;
    margin: 0;
    font-family: monospace;
    color:DimGray;
    border-radius: 2px
}

h3 {
    text-align: center;
    background-color: pink;
    padding: 10px;
    margin: 0;
    font-family: monospace;
    color:DimGray;
    border-radius: 2px
}

h4 {
    text-align: center;
    background-color: pink;
    padding: 10px;
    margin: 0;
    font-family: monospace;
    color:DimGray;
    border-radius: 2px
}

body, p {
    font-family: monospace;
    font-size: 18px;
    color: charcoal;
}
div {
    font-size: 14px;
    margin: 0;

}
</style>
""")
# Out:
# <style>
# .output_png {
#     display: table-cell;
#     text-align: center;
#     vertical-align: middle;
#     horizontal-align: middle;
# }
# h1 {
#     text-align: center;
#     background-color: #6bacf5;
#     padding: 10px;
#     margin: 0;
#     font-family: monospace;
#     color:DimGray;
#     border-radius: 2px
#     style="font-family:verdana;"
# }
#
# h2 {
#     text-align: center;
#     background-color: #83c2ff;
#     padding: 10px;
#     margin: 0;
#     font-family: monospace;
#     color:DimGray;
#     border-radius: 2px
# }
#
# h3 {
#     text-align: center;
#     background-color: pink;
#     padding: 10px;
#     margin: 0;
#     font-family: monospace;
#     color:DimGray;
#     border-radius: 2px
# }
#
# h4 {
#     text-align: center;
#     background-color: pink;
#     padding: 10px;
#     margin: 0;
#     font-family: monospace;
#     color:DimGray;
#     border-radius: 2px
# }
#
# body, p {
#     font-family: monospace;
#     font-size: 18px;
#     color: charcoal;
# }
# div {
#     font-size: 14px;
#     margin: 0;
#
# }
# </style>

# %% [markdown]
# # TUTORIAL HOW TO USE LANGCHAIN AND VECTOR DATABASES TO USE OUR OWN DOCUMENTS WITH HUGGING FACES
#
# In a [previous notebook](https://www.kaggle.com/code/peremartramanonellas/use-a-vectorial-db-to-optimize-prompts-for-llms), we saw how to use a vectorial database to create an enriched prompt for Hugging Face language models. In this one, we incorporate LangChain so that we can make queries to the language model that take into account our information.
#
# The information could be our own documents, or whatever was contained in a business knowledge database.
#
# I have prepared the notebook so that it can work with two different Kaggle datasets, so that it is easy to carry out different tests with different Datasets.
#
# The data has been loaded from a Pandas DataFrame, using the **DataFrameLoader** function from the **document_loaders** library of **LangChain**.
#
# ### Feel Free to fork or edit the noteboook for you own convenience. Please consider ***UPVOTING IT***. It helps others to discover the notebook, and it encourages me to continue publishing.

# %% [markdown]
# # Install and load the libraries.
# To start we need to install the necesary Python packages.
# * **[langchain](https://python.langchain.com/docs/get_started/introduction.html)**. The revolutionary framework to build apps using large language models.
# * **[sentence_transformers](https://www.sbert.net/)**. necesary to create the embeddings we are going to store in the vector database.
# * **[chromadb](https://www.trychroma.com/)**. This is our vector Database. ChromaDB is easy to use and open source, maybe the most used Vector Database used to store embeddings.

# %%
# !pip install chromadb
# !pip install langchain
# !pip install sentence_transformers
# Out:
# Collecting chromadb
#   Downloading chromadb-0.4.2-py3-none-any.whl (399 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 399.3/399.3 kB 7.8 MB/s eta 0:00:00
# Requirement already satisfied: pandas>=1.3 in /opt/conda/lib/python3.10/site-packages (from chromadb) (1.5.3)
# Requirement already satisfied: requests>=2.28 in /opt/conda/lib/python3.10/site-packages (from chromadb) (2.31.0)
# Requirement already satisfied: pydantic<2.0,>=1.9 in /opt/conda/lib/python3.10/site-packages (from chromadb) (1.10.9)
# Collecting chroma-hnswlib==0.7.1 (from chromadb)
#   Downloading chroma-hnswlib-0.7.1.tar.gz (30 kB)
# done
# done
# done
# Requirement already satisfied: fastapi<0.100.0,>=0.95.2 in /opt/conda/lib/python3.10/site-packages (from chromadb) (0.98.0)
# Requirement already satisfied: uvicorn[standard]>=0.18.3 in /opt/conda/lib/python3.10/site-packages (from chromadb) (0.22.0)
# Requirement already satisfied: numpy>=1.21.6 in /opt/conda/lib/python3.10/site-packages (from chromadb) (1.23.5)
# Collecting posthog>=2.4.0 (from chromadb)
#   Downloading posthog-3.0.1-py2.py3-none-any.whl (37 kB)
# Requirement already satisfied: typing-extensions>=4.5.0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (4.6.3)
# Collecting pulsar-client>=3.1.0 (from chromadb)
#   Downloading pulsar_client-3.2.0-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.3 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.3/5.3 MB 57.7 MB/s eta 0:00:00
# Collecting onnxruntime>=1.14.1 (from chromadb)
#   Downloading onnxruntime-1.15.1-cp310-cp310-manylinux_2_17_x86_64.manylinux2014_x86_64.whl (5.9 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 5.9/5.9 MB 66.7 MB/s eta 0:00:00
# Requirement already satisfied: tokenizers>=0.13.2 in /opt/conda/lib/python3.10/site-packages (from chromadb) (0.13.3)
# Collecting pypika>=0.48.9 (from chromadb)
#   Downloading PyPika-0.48.9.tar.gz (67 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 67.3/67.3 kB 5.1 MB/s eta 0:00:00
# done
# done
# done
# Requirement already satisfied: tqdm>=4.65.0 in /opt/conda/lib/python3.10/site-packages (from chromadb) (4.65.0)
# Collecting overrides>=7.3.1 (from chromadb)
#   Downloading overrides-7.3.1-py3-none-any.whl (17 kB)
# Requirement already satisfied: importlib-resources in /opt/conda/lib/python3.10/site-packages (from chromadb) (5.12.0)
# Requirement already satisfied: starlette<0.28.0,>=0.27.0 in /opt/conda/lib/python3.10/site-packages (from fastapi<0.100.0,>=0.95.2->chromadb) (0.27.0)
# Collecting coloredlogs (from onnxruntime>=1.14.1->chromadb)
#   Downloading coloredlogs-15.0.1-py2.py3-none-any.whl (46 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 46.0/46.0 kB 3.3 MB/s eta 0:00:00
# Requirement already satisfied: flatbuffers in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (23.5.26)
# Requirement already satisfied: packaging in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (21.3)
# Requirement already satisfied: protobuf in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (3.20.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from onnxruntime>=1.14.1->chromadb) (1.12)
# Requirement already satisfied: python-dateutil>=2.8.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3->chromadb) (2.8.2)
# Requirement already satisfied: pytz>=2020.1 in /opt/conda/lib/python3.10/site-packages (from pandas>=1.3->chromadb) (2023.3)
# Requirement already satisfied: six>=1.5 in /opt/conda/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (1.16.0)
# Collecting monotonic>=1.5 (from posthog>=2.4.0->chromadb)
#   Downloading monotonic-1.6-py2.py3-none-any.whl (8.2 kB)
# Requirement already satisfied: backoff>=1.10.0 in /opt/conda/lib/python3.10/site-packages (from posthog>=2.4.0->chromadb) (2.2.1)
# Requirement already satisfied: certifi in /opt/conda/lib/python3.10/site-packages (from pulsar-client>=3.1.0->chromadb) (2023.5.7)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests>=2.28->chromadb) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests>=2.28->chromadb) (1.26.15)
# Requirement already satisfied: click>=7.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (8.1.3)
# Requirement already satisfied: h11>=0.8 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.14.0)
# Requirement already satisfied: httptools>=0.5.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.6.0)
# Requirement already satisfied: python-dotenv>=0.13 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (1.0.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (6.0)
# Requirement already satisfied: uvloop!=0.15.0,!=0.15.1,>=0.14.0 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.17.0)
# Requirement already satisfied: watchfiles>=0.13 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (0.19.0)
# Requirement already satisfied: websockets>=10.4 in /opt/conda/lib/python3.10/site-packages (from uvicorn[standard]>=0.18.3->chromadb) (11.0.3)
# Requirement already satisfied: anyio<5,>=3.4.0 in /opt/conda/lib/python3.10/site-packages (from starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (3.7.0)
# Collecting humanfriendly>=9.1 (from coloredlogs->onnxruntime>=1.14.1->chromadb)
#   Downloading humanfriendly-10.0-py2.py3-none-any.whl (86 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.8/86.8 kB 7.3 MB/s eta 0:00:00
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging->onnxruntime>=1.14.1->chromadb) (3.0.9)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->onnxruntime>=1.14.1->chromadb) (1.3.0)
# Requirement already satisfied: sniffio>=1.1 in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.3.0)
# Requirement already satisfied: exceptiongroup in /opt/conda/lib/python3.10/site-packages (from anyio<5,>=3.4.0->starlette<0.28.0,>=0.27.0->fastapi<0.100.0,>=0.95.2->chromadb) (1.1.1)
# Building wheels for collected packages: chroma-hnswlib, pypika
# done
#   Created wheel for chroma-hnswlib: filename=chroma_hnswlib-0.7.1-cp310-cp310-linux_x86_64.whl size=193356 sha256=8005ff1ea33c38a0fa65216b302c5cb2bd769f87fce0473c09212c94fab94915
#   Stored in directory: /root/.cache/pip/wheels/ad/f2/d2/3f32228e9f4713a9f32a468de8bbc3c642f7805ebef888418b
# done
#   Created wheel for pypika: filename=PyPika-0.48.9-py2.py3-none-any.whl size=53723 sha256=8b9f375aab1e5487a3b2e3d53c97157dba9b86f7ef29a13b094f52fcd58594ef
#   Stored in directory: /root/.cache/pip/wheels/e1/26/51/d0bffb3d2fd82256676d7ad3003faea3bd6dddc9577af665f4
# Successfully built chroma-hnswlib pypika
# Installing collected packages: pypika, monotonic, pulsar-client, overrides, humanfriendly, chroma-hnswlib, posthog, coloredlogs, onnxruntime, chromadb
#   Attempting uninstall: overrides
#     Found existing installation: overrides 6.5.0
#     Uninstalling overrides-6.5.0:
#       Successfully uninstalled overrides-6.5.0
# ERROR: pip's dependency resolver does not currently take into account all the packages that are installed. This behaviour is the source of the following dependency conflicts.
# google-cloud-pubsublite 1.8.2 requires overrides<7.0.0,>=6.0.1, but you have overrides 7.3.1 which is incompatible.
# jupyterlab-lsp 4.2.0 requires jupyter-lsp>=2.0.0, but you have jupyter-lsp 1.5.1 which is incompatible.
# Successfully installed chroma-hnswlib-0.7.1 chromadb-0.4.2 coloredlogs-15.0.1 humanfriendly-10.0 monotonic-1.6 onnxruntime-1.15.1 overrides-7.3.1 posthog-3.0.1 pulsar-client-3.2.0 pypika-0.48.9
# Collecting langchain
#   Downloading langchain-0.0.240-py3-none-any.whl (1.4 MB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.4/1.4 MB 18.6 MB/s eta 0:00:00
# Requirement already satisfied: PyYAML>=5.4.1 in /opt/conda/lib/python3.10/site-packages (from langchain) (6.0)
# Requirement already satisfied: SQLAlchemy<3,>=1.4 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.0.17)
# Requirement already satisfied: aiohttp<4.0.0,>=3.8.3 in /opt/conda/lib/python3.10/site-packages (from langchain) (3.8.4)
# Requirement already satisfied: async-timeout<5.0.0,>=4.0.0 in /opt/conda/lib/python3.10/site-packages (from langchain) (4.0.2)
# Requirement already satisfied: dataclasses-json<0.6.0,>=0.5.7 in /opt/conda/lib/python3.10/site-packages (from langchain) (0.5.9)
# Collecting langsmith<0.1.0,>=0.0.11 (from langchain)
#   Downloading langsmith-0.0.14-py3-none-any.whl (29 kB)
# Requirement already satisfied: numexpr<3.0.0,>=2.8.4 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.8.4)
# Requirement already satisfied: numpy<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain) (1.23.5)
# Collecting openapi-schema-pydantic<2.0,>=1.2 (from langchain)
#   Downloading openapi_schema_pydantic-1.2.4-py3-none-any.whl (90 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 90.0/90.0 kB 8.5 MB/s eta 0:00:00
# Requirement already satisfied: pydantic<2,>=1 in /opt/conda/lib/python3.10/site-packages (from langchain) (1.10.9)
# Requirement already satisfied: requests<3,>=2 in /opt/conda/lib/python3.10/site-packages (from langchain) (2.31.0)
# Requirement already satisfied: tenacity<9.0.0,>=8.1.0 in /opt/conda/lib/python3.10/site-packages (from langchain) (8.2.2)
# Requirement already satisfied: attrs>=17.3.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (23.1.0)
# Requirement already satisfied: charset-normalizer<4.0,>=2.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (3.1.0)
# Requirement already satisfied: multidict<7.0,>=4.5 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (6.0.4)
# Requirement already satisfied: yarl<2.0,>=1.0 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.9.2)
# Requirement already satisfied: frozenlist>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.3)
# Requirement already satisfied: aiosignal>=1.1.2 in /opt/conda/lib/python3.10/site-packages (from aiohttp<4.0.0,>=3.8.3->langchain) (1.3.1)
# Requirement already satisfied: marshmallow<4.0.0,>=3.3.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (3.19.0)
# Requirement already satisfied: marshmallow-enum<2.0.0,>=1.5.1 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (1.5.1)
# Requirement already satisfied: typing-inspect>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from dataclasses-json<0.6.0,>=0.5.7->langchain) (0.9.0)
# Requirement already satisfied: typing-extensions>=4.2.0 in /opt/conda/lib/python3.10/site-packages (from pydantic<2,>=1->langchain) (4.6.3)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests<3,>=2->langchain) (2023.5.7)
# Requirement already satisfied: greenlet!=0.4.17 in /opt/conda/lib/python3.10/site-packages (from SQLAlchemy<3,>=1.4->langchain) (2.0.2)
# Requirement already satisfied: packaging>=17.0 in /opt/conda/lib/python3.10/site-packages (from marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (21.3)
# Requirement already satisfied: mypy-extensions>=0.3.0 in /opt/conda/lib/python3.10/site-packages (from typing-inspect>=0.4.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (1.0.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=17.0->marshmallow<4.0.0,>=3.3.0->dataclasses-json<0.6.0,>=0.5.7->langchain) (3.0.9)
# Installing collected packages: openapi-schema-pydantic, langsmith, langchain
# Successfully installed langchain-0.0.240 langsmith-0.0.14 openapi-schema-pydantic-1.2.4
# Collecting sentence_transformers
#   Downloading sentence-transformers-2.2.2.tar.gz (85 kB)
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 86.0/86.0 kB 3.2 MB/s eta 0:00:00
# done
# Requirement already satisfied: transformers<5.0.0,>=4.6.0 in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (4.30.2)
# Requirement already satisfied: tqdm in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (4.65.0)
# Requirement already satisfied: torch>=1.6.0 in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (2.0.0+cpu)
# Requirement already satisfied: torchvision in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (0.15.1+cpu)
# Requirement already satisfied: numpy in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.23.5)
# Requirement already satisfied: scikit-learn in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.2.2)
# Requirement already satisfied: scipy in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (1.11.1)
# Requirement already satisfied: nltk in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (3.2.4)
# Requirement already satisfied: sentencepiece in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (0.1.99)
# Requirement already satisfied: huggingface-hub>=0.4.0 in /opt/conda/lib/python3.10/site-packages (from sentence_transformers) (0.16.4)
# Requirement already satisfied: filelock in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (3.12.2)
# Requirement already satisfied: fsspec in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2023.6.0)
# Requirement already satisfied: requests in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (2.31.0)
# Requirement already satisfied: pyyaml>=5.1 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (6.0)
# Requirement already satisfied: typing-extensions>=3.7.4.3 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (4.6.3)
# Requirement already satisfied: packaging>=20.9 in /opt/conda/lib/python3.10/site-packages (from huggingface-hub>=0.4.0->sentence_transformers) (21.3)
# Requirement already satisfied: sympy in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (1.12)
# Requirement already satisfied: networkx in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (3.1)
# Requirement already satisfied: jinja2 in /opt/conda/lib/python3.10/site-packages (from torch>=1.6.0->sentence_transformers) (3.1.2)
# Requirement already satisfied: regex!=2019.12.17 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (2023.6.3)
# Requirement already satisfied: tokenizers!=0.11.3,<0.14,>=0.11.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.13.3)
# Requirement already satisfied: safetensors>=0.3.1 in /opt/conda/lib/python3.10/site-packages (from transformers<5.0.0,>=4.6.0->sentence_transformers) (0.3.1)
# Requirement already satisfied: six in /opt/conda/lib/python3.10/site-packages (from nltk->sentence_transformers) (1.16.0)
# Requirement already satisfied: joblib>=1.1.1 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (1.2.0)
# Requirement already satisfied: threadpoolctl>=2.0.0 in /opt/conda/lib/python3.10/site-packages (from scikit-learn->sentence_transformers) (3.1.0)
# Requirement already satisfied: pillow!=8.3.*,>=5.3.0 in /opt/conda/lib/python3.10/site-packages (from torchvision->sentence_transformers) (9.5.0)
# Requirement already satisfied: pyparsing!=3.0.5,>=2.0.2 in /opt/conda/lib/python3.10/site-packages (from packaging>=20.9->huggingface-hub>=0.4.0->sentence_transformers) (3.0.9)
# Requirement already satisfied: MarkupSafe>=2.0 in /opt/conda/lib/python3.10/site-packages (from jinja2->torch>=1.6.0->sentence_transformers) (2.1.3)
# Requirement already satisfied: charset-normalizer<4,>=2 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.1.0)
# Requirement already satisfied: idna<4,>=2.5 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (3.4)
# Requirement already satisfied: urllib3<3,>=1.21.1 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /opt/conda/lib/python3.10/site-packages (from requests->huggingface-hub>=0.4.0->sentence_transformers) (2023.5.7)
# Requirement already satisfied: mpmath>=0.19 in /opt/conda/lib/python3.10/site-packages (from sympy->torch>=1.6.0->sentence_transformers) (1.3.0)
# Building wheels for collected packages: sentence_transformers
# done
#   Created wheel for sentence_transformers: filename=sentence_transformers-2.2.2-py3-none-any.whl size=125938 sha256=0f114fd576f3358314f791c7c617eebc2f0cdece58fb28064a15074706a4f315
#   Stored in directory: /root/.cache/pip/wheels/62/f2/10/1e606fd5f02395388f74e7462910fe851042f97238cbbd902f
# Successfully built sentence_transformers
# Installing collected packages: sentence_transformers
# Successfully installed sentence_transformers-2.2.2

# %% [markdown]
# I'm sure that you know the next two packages: Numpy and Pandas, maybe the most used python libraries.
#
# Numpy is a powerful library for numerical computing.
#
# Pandas is a library for data manipulation

# %%
import numpy as np 
import pandas as pd

# %% [markdown]
# # Load the Dataset
# As you can see the notebook is ready to work with two different Datasets. Just uncomment the lines of the Dataset you want to use.
#
# As we are working in a free and limited space, and we can use just 30 gb of memory I limited the number of news to use with the variable MAX_NEWS. If you are using a GPU your memoty will be limited to 16GB.
#
# The name of the field containing the text of the new is stored in the variable *DOCUMENT* and the metadata in *TOPIC*

# %%
news = pd.read_csv('/kaggle/input/topic-labeled-news-dataset/labelled_newscatcher_dataset.csv', sep=';')
MAX_NEWS = 1000
DOCUMENT="title"
TOPIC="topic"

#news = pd.read_csv('/kaggle/input/bbc-news/bbc_news.csv')
#MAX_NEWS = 500
#DOCUMENT="description"
#TOPIC="title"

#Because it is just a course we select a small portion of News.
subset_news = news.head(MAX_NEWS)

# %% [markdown]
# ## CREATE THE DOCUMENT FROM THE DATAFRAME
# We are going to load the data from a pandas DataFrame. However, LangChain, through the document_loader library, supports multiple data sources, such as Word documents, Excel files, plain text, SQL, and more.
#
# We also imported the Chroma library, which is used to save the embeddings in the ChromaDB database.

# %%
from langchain.document_loaders import DataFrameLoader
from langchain.vectorstores import Chroma

# %% [markdown]
# First, we create the loader, indicating the data source and the name of the column in the DataFrame where we store what we could consider as the document, that is, the information we want to pass to the model so that it takes it into account in its responses.

# %%
df_loader = DataFrameLoader(subset_news, page_content_column=DOCUMENT)

# %% [markdown]
# Then, we use the loader to load the document.

# %%
df_document = df_loader.load()

# %%
display(df_document)
# Out:
# [Document(page_content="A closer look at water-splitting's solar fuel potential", metadata={'topic': 'SCIENCE', 'link': 'https://www.eurekalert.org/pub_releases/2020-08/dbnl-acl080620.php', 'domain': 'eurekalert.org', 'published_date': '2020-08-06 13:59:45', 'lang': 'en'}),
#  Document(page_content='An irresistible scent makes locusts swarm, study finds', metadata={'topic': 'SCIENCE', 'link': 'https://www.pulse.ng/news/world/an-irresistible-scent-makes-locusts-swarm-study-finds/jy784jw', 'domain': 'pulse.ng', 'published_date': '2020-08-12 15:14:19', 'lang': 'en'}),
#  Document(page_content='Artificial intelligence warning: AI will know us better than we know ourselves', metadata={'topic': 'SCIENCE', 'link': 'https://www.express.co.uk/news/science/1322607/artificial-intelligence-warning-machine-learning-algorithm-social-media-data', 'domain': 'express.co.uk', 'published_date': '2020-08-13 21:01:00', 'lang': 'en'}),
#  Document(page_content='Glaciers Could Have Sculpted Mars Valleys: Study', metadata={'topic': 'SCIENCE', 'link': 'https://www.ndtv.com/world-news/glaciers-could-have-sculpted-mars-valleys-study-2273648', 'domain': 'ndtv.com', 'published_date': '2020-08-03 22:18:26', 'lang': 'en'}),
#  Document(page_content='Perseid meteor shower 2020: What time and how to see the huge bright FIREBALLS over UK again tonight', metadata={'topic': 'SCIENCE', 'link': 'https://www.thesun.ie/tech/5742187/perseid-meteor-shower-tonight-time-uk-see/', 'domain': 'thesun.ie', 'published_date': '2020-08-12 19:54:36', 'lang': 'en'}),
#  Document(page_content='NASA Releases In-Depth Map of Beirut Explosion Damage', metadata={'topic': 'SCIENCE', 'link': 'https://interestingengineering.com/nasa-releases-in-depth-map-of-beirut-explosion-damage', 'domain': 'interestingengineering.com', 'published_date': '2020-08-08 11:05:45', 'lang': 'en'}),
#  Document(page_content='SpaceX, NASA Demo-2 Rocket Launch Set for Saturday: How to Watch', metadata={'topic': 'SCIENCE', 'link': 'https://www.thequint.com/tech-and-auto/spacex-nasa-demo-2-rocket-launch-set-for-saturday-how-to-watch', 'domain': 'thequint.com', 'published_date': '2020-05-28 09:09:46', 'lang': 'en'}),
#  Document(page_content='Orbital space tourism set for rebirth in 2021', metadata={'topic': 'SCIENCE', 'link': 'https://www.thespacereview.com/article/4003/1', 'domain': 'thespacereview.com', 'published_date': '2020-08-10 22:48:23', 'lang': 'en'}),
#  Document(page_content="Greenland's melting ice sheet has 'passed the point of no return'", metadata={'topic': 'SCIENCE', 'link': 'https://www.businessinsider.com/greenland-melting-ice-sheet-past-tipping-point-2020-8', 'domain': 'businessinsider.com', 'published_date': '2020-08-16 00:28:54', 'lang': 'en'}),
#  Document(page_content='NASA invites engineering students to help harvest water on Mars, Moon', metadata={'topic': 'SCIENCE', 'link': 'https://www.thehindubusinessline.com/news/science/nasa-invites-engineering-students-to-help-harvest-water-on-mars-moon/article32352915.ece', 'domain': 'thehindubusinessline.com', 'published_date': '2020-08-14 07:43:25', 'lang': 'en'}),
#  Document(page_content='Astronomers Detect Electromagnetic Signal Caused by Unequal Neutron-Star Collision', metadata={'topic': 'SCIENCE', 'link': 'https://www.azoquantum.com/News.aspx?newsID=7321', 'domain': 'azoquantum.com', 'published_date': '2020-08-04 14:02:00', 'lang': 'en'}),
#  Document(page_content="NASA Finds Ammonia-Linked 'Mushballs' and 'Shallow Lightning' on Jupiter", metadata={'topic': 'SCIENCE', 'link': 'https://interestingengineering.com/nasa-finds-ammonia-linked-mushballs-and-shallow-lightning-on-jupiter', 'domain': 'interestingengineering.com', 'published_date': '2020-08-07 09:23:57', 'lang': 'en'}),
#  Document(page_content='Russia targets returning to Venus, build reusable rocket', metadata={'topic': 'SCIENCE', 'link': 'https://menafn.com/1100601885/Russia-targets-returning-to-Venus-build-reusable-rocket', 'domain': 'menafn.com', 'published_date': '2020-08-07 22:05:55', 'lang': 'en'}),
#  Document(page_content='Martian Night Sky Pulses in Ultraviolet Light', metadata={'topic': 'SCIENCE', 'link': 'https://www.nasa.gov/press-release/goddard/2020/mars-nightglow/', 'domain': 'nasa.gov', 'published_date': '2020-08-06 16:28:32', 'lang': 'en'}),
#  Document(page_content='Energy-Efficient Tuning of Spintronic Neurons to Imitate the Non-linear Oscillatory Neural Networks of the Human Brain', metadata={'topic': 'SCIENCE', 'link': 'https://scitechdaily.com/energy-efficient-tuning-of-spintronic-neurons-to-imitate-the-non-linear-oscillatory-neural-networks-of-the-human-brain/', 'domain': 'scitechdaily.com', 'published_date': '2020-08-17 14:23:19', 'lang': 'en'}),
#  Document(page_content="Scientists may have discovered the Achilles' heel of the coronavirus", metadata={'topic': 'SCIENCE', 'link': 'https://www.theladders.com/career-advice/scientists-may-have-discovered-the-achilles-heel-of-the-coronavirus', 'domain': 'theladders.com', 'published_date': '2020-08-14 19:58:55', 'lang': 'en'}),
#  Document(page_content='Tradeoff between the eyes and nose helps flies find their niche', metadata={'topic': 'SCIENCE', 'link': 'https://www.eurekalert.org/pub_releases/2020-08/e-tbt080420.php', 'domain': 'eurekalert.org', 'published_date': '2020-08-04 16:02:36', 'lang': 'en'}),
#  Document(page_content="2020's final Mars mission poised for blastoff from Florida", metadata={'topic': 'SCIENCE', 'link': 'https://kearneyhub.com/news/national/2020s-final-mars-mission-poised-for-blastoff-from-florida/article_241d8506-ac89-56f5-8472-6c5f8423523d.html', 'domain': 'kearneyhub.com', 'published_date': '2020-08-08 17:13:07', 'lang': 'en'}),
#  Document(page_content='In rare find, fossil shows how Cretaceous-era ‘hell ant’ ate its prey with weird jaws', metadata={'topic': 'SCIENCE', 'link': 'https://www.washingtonpost.com/science/ant-behavior-evolution-fossil/2020/08/14/a246197c-dcd6-11ea-809e-b8be57ba616e_story.html', 'domain': 'washingtonpost.com', 'published_date': '2020-08-15 12:00:00', 'lang': 'en'}),
#  Document(page_content='Nasa SpaceX crew return: Dragon capsule splashes down', metadata={'topic': 'SCIENCE', 'link': 'https://www.rnz.co.nz/news/world/422607/nasa-spacex-crew-return-dragon-capsule-splashes-down', 'domain': 'rnz.co.nz', 'published_date': '2020-08-02 18:50:38', 'lang': 'en'}),
#  Document(page_content='Take a look at Mar’s eerie nightglow', metadata={'topic': 'SCIENCE', 'link': 'https://www.techexplorist.com/look-mars-eerie-nightglow/34341/', 'domain': 'techexplorist.com', 'published_date': '2020-08-07 11:17:00', 'lang': 'en'}),
#  Document(page_content='CERN Scientists Discover Rare Higgs Boson Process', metadata={'topic': 'SCIENCE', 'link': 'https://interestingengineering.com/cern-scientists-discover-rare-higgs-boson-process', 'domain': 'interestingengineering.com', 'published_date': '2020-08-05 13:08:05', 'lang': 'en'}),
#  Document(page_content="'Beautiful and healthy' young woman died suddenly on dream work trip in Australia", metadata={'topic': 'SCIENCE', 'link': 'https://www.liverpoolecho.co.uk/news/liverpool-news/beautiful-healthy-young-woman-died-18747884', 'domain': 'liverpoolecho.co.uk', 'published_date': '2020-08-11 04:00:00', 'lang': 'en'}),
#  Document(page_content='Hubble Uses Moon As “Mirror” to Study Earth’s Atmosphere – Proxy in Search of Potentially Habitable Planets Around Other Stars', metadata={'topic': 'SCIENCE', 'link': 'https://scitechdaily.com/hubble-uses-moon-as-mirror-to-study-earths-atmosphere-proxy-in-search-of-potentially-habitable-planets-around-other-stars/', 'domain': 'scitechdaily.com', 'published_date': '2020-08-06 14:28:45', 'lang': 'en'}),
#  Document(page_content='Indian researchers show how Covid-19 PPE can turn into biofuel', metadata={'topic': 'SCIENCE', 'link': 'https://www.daijiworld.com/news/newsDisplay.aspx?newsID=737478', 'domain': 'daijiworld.com', 'published_date': '2020-08-04 10:07:36', 'lang': 'en'}),
#  Document(page_content='ATLANTIC SKIES: Young astronomers and the Perseid meteors', metadata={'topic': 'SCIENCE', 'link': 'https://www.thechronicleherald.ca/lifestyles/regional-lifestyles/atlantic-skies-young-astronomers-and-the-perseid-meteors-481695/', 'domain': 'thechronicleherald.ca', 'published_date': '2020-08-07 10:11:08', 'lang': 'en'}),
#  Document(page_content='‘It came alive:’ NASA astronauts describe experiencing splashdown in SpaceX Dragon', metadata={'topic': 'SCIENCE', 'link': 'https://www.clickorlando.com/news/local/2020/08/04/nasa-astronauts-to-talk-about-historic-spacex-splashdown/', 'domain': 'clickorlando.com', 'published_date': '2020-08-04 23:21:00', 'lang': 'en'}),
#  Document(page_content='When did humans find out how to use fire?', metadata={'topic': 'SCIENCE', 'link': 'https://www.sproutwired.com/when-did-humans-find-out-how-to-use-fire/', 'domain': 'sproutwired.com', 'published_date': '2020-08-08 15:00:00', 'lang': 'en'}),
#  Document(page_content='Like Your First Quarantine Sourdough Attempt, This Exoplanet Is "Surprisingly Dense"', metadata={'topic': 'SCIENCE', 'link': 'https://futurism.com/the-byte/sourdough-exoplanet-surprisingly-dense', 'domain': 'futurism.com', 'published_date': '2020-08-04 07:00:00', 'lang': 'en'}),
#  Document(page_content='Ring-like Structure on Ganymede May Have Been Caused by a Violent Impact', metadata={'topic': 'SCIENCE', 'link': 'https://www.heritagedaily.com/2020/08/ring-like-structure-on-ganymede-may-have-been-caused-by-a-violent-impact/134643', 'domain': 'heritagedaily.com', 'published_date': '2020-08-07 22:11:40', 'lang': 'en'}),
#  Document(page_content='NASA drops "insensitive" nicknames for cosmic objects', metadata={'topic': 'SCIENCE', 'link': 'https://www.cbsnews.com/news/nasa-drops-insensitive-nicknames-cosmic-objects/', 'domain': 'cbsnews.com', 'published_date': '2020-08-08 18:39:00', 'lang': 'en'}),
#  Document(page_content='Archaeology: A 2,700-year-old inscription in Jerusalem proves Bible RIGHT, expert claims', metadata={'topic': 'SCIENCE', 'link': 'https://www.express.co.uk/news/science/1323379/Archaeology-news-Jerusalem-Siloam-Tunnel-inscription-Hezekiah-Bible-accurate', 'domain': 'express.co.uk', 'published_date': '2020-08-16 09:01:00', 'lang': 'en'}),
#  Document(page_content='Mars helicopter reaches "big milestone" on flight to planet', metadata={'topic': 'SCIENCE', 'link': 'https://www.cbsnews.com/news/mars-helicopter-ingenuity-milestone-perseverance-rover/', 'domain': 'cbsnews.com', 'published_date': '2020-08-17 11:22:00', 'lang': 'en'}),
#  Document(page_content='Sunspot the size of Mars is turning towards Earth', metadata={'topic': 'SCIENCE', 'link': 'https://www.dailymail.co.uk/sciencetech/article-8612449/Sunspot-size-Mars-turning-Earth-solar-flares-affect-electronics.html', 'domain': 'dailymail.co.uk', 'published_date': '2020-08-10 15:51:55', 'lang': 'en'}),
#  Document(page_content="Jupiter's huge moon Ganymede may have the largest impact scar in the solar system", metadata={'topic': 'SCIENCE', 'link': 'https://www.space.com/jupiter-moon-ganymede-giant-impact-scar.html', 'domain': 'space.com', 'published_date': '2020-08-07 20:44:00', 'lang': 'en'}),
#  Document(page_content='Man posts mind-blowing TikTok from highest point in Canada to disprove Flat Earth theory', metadata={'topic': 'SCIENCE', 'link': 'https://www.mirror.co.uk/science/man-posts-mind-blowing-tiktok-22521686', 'domain': 'mirror.co.uk', 'published_date': '2020-08-14 11:58:00', 'lang': 'en'}),
#  Document(page_content='Cause Of Massive Fish Kill In Shinnecock Canal Not Clear - 27 East', metadata={'topic': 'SCIENCE', 'link': 'https://www.27east.com/southampton-press/cause-of-massive-fish-kill-in-shinnecock-canal-not-clear-2-1479054/', 'domain': '27east.com', 'published_date': '2019-11-23 16:07:14', 'lang': 'en'}),
#  Document(page_content='Unequal neutron-star mergers create unique "bang" in simulations', metadata={'topic': 'SCIENCE', 'link': 'https://www.eurekalert.org/pub_releases/2020-08/ps-unm080320.php', 'domain': 'eurekalert.org', 'published_date': '2020-08-03 20:17:32', 'lang': 'en'}),
#  Document(page_content="'Zombie cicadas' under the influence of a mind controlling fungus have returned to West Virginia", metadata={'topic': 'SCIENCE', 'link': 'https://www.cnn.com/2020/08/03/us/zombie-cicadas-west-virginia-fungus-scn-trnd/index.html', 'domain': 'cnn.com', 'published_date': '2020-08-03 21:59:00', 'lang': 'en'}),
#  Document(page_content="Astronomers May Have Found a Lost Neutron Star That's Been Missing For Decades", metadata={'topic': 'SCIENCE', 'link': 'https://www.sciencealert.com/astronomers-may-have-just-found-a-missing-baby-neutron-star', 'domain': 'sciencealert.com', 'published_date': '2020-08-04 06:01:29', 'lang': 'en'}),
#  Document(page_content="SpaceX's Starship spacecraft saw 150 meters high", metadata={'topic': 'SCIENCE', 'link': 'https://www.somagnews.com/spacexs-starship-spacecraft-saw-150-meters-high/', 'domain': 'somagnews.com', 'published_date': '2020-08-05 17:12:00', 'lang': 'en'}),
#  Document(page_content="These Orbs Look Like Candy, But They're Actually Different Flavours of Phobos", metadata={'topic': 'SCIENCE', 'link': 'https://www.sciencealert.com/these-orbs-look-like-candy-but-they-re-actually-different-flavours-of-a-martian-moon', 'domain': 'sciencealert.com', 'published_date': '2020-08-13 23:23:31', 'lang': 'en'}),
#  Document(page_content='Come See What It’s Like To Play Microsoft Flight Simulator', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.kotaku.com.au/2020/08/come-see-what-its-like-to-play-microsoft-flight-simulator/', 'domain': 'kotaku.com.au', 'published_date': '2020-08-14 06:29:00', 'lang': 'en'}),
#  Document(page_content='Xiaomi rolls out Android 10 to the Redmi Note 7 Pro in India as Mi Note 10 and Redmi Note 8 Pro receive new MIUI 12 upgrades', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.notebookcheck.net/Xiaomi-rolls-out-Android-10-to-the-Redmi-Note-7-Pro-in-India-as-Mi-Note-10-and-Redmi-Note-8-Pro-receive-new-MIUI-12-upgrades.485157.0.html', 'domain': 'notebookcheck.net', 'published_date': '2020-08-11 16:17:38', 'lang': 'en'}),
#  Document(page_content="Xiaomi's Mi 10 Ultra has 120x zoom and can fully charge in 23 minutes", metadata={'topic': 'TECHNOLOGY', 'link': 'https://sea.mashable.com/tech/11935/xiaomis-mi-10-ultra-has-120x-zoom-and-can-fully-charge-in-23-minutes', 'domain': 'sea.mashable.com', 'published_date': '2020-08-12 14:28:00', 'lang': 'en'}),
#  Document(page_content='Google will test new feature in Chrome to curb phishing', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.welivesecurity.com/2020/08/14/google-test-new-feature-chrome-phishing/', 'domain': 'welivesecurity.com', 'published_date': '2020-08-14 15:12:04', 'lang': 'en'}),
#  Document(page_content='TikTok creators say they’re not switching to Instagram Reels: survey', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.digitaltrends.com/news/tiktok-creators-say-theyre-not-switching-to-instagram-reels-survey/', 'domain': 'digitaltrends.com', 'published_date': '2020-08-12 19:12:00', 'lang': 'en'}),
#  Document(page_content='NASA’s InSight lander shows what’s beneath Mars’ surface', metadata={'topic': 'SCIENCE', 'link': 'https://www.digitaltrends.com/news/nasa-insight-mars-subsurface-boundaries/', 'domain': 'digitaltrends.com', 'published_date': '2020-08-09 13:24:00', 'lang': 'en'}),
#  Document(page_content='EVE Echoes Releases On iOS and Android Today', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.mmorpg.com/eve-echoes/videos/eve-echoes-releases-on-ios-and-android-today-2000119099', 'domain': 'mmorpg.com', 'published_date': '2020-08-13 22:14:49', 'lang': 'en'}),
#  Document(page_content='YouTuber mounts GoPro inside his tire', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.topgear.com.ph/features/feature-articles/gopro-inside-tire-a962-20200803', 'domain': 'topgear.com.ph', 'published_date': '2020-08-03 05:37:00', 'lang': 'en'}),
#  Document(page_content='Google discontinues Pixel 4 and Pixel 4 XL after less than a year [Updated]', metadata={'topic': 'TECHNOLOGY', 'link': 'https://9to5google.com/2020/08/05/google-discontinues-pixel-4/', 'domain': '9to5google.com', 'published_date': '2020-08-06 06:50:00', 'lang': 'en'}),
#  Document(page_content="Facebook, Microsoft gripes with Apple's App Store on EU's antitrust radar", metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.kitco.com/news/2020-08-10/Facebook-Microsoft-gripes-with-Apple-s-App-Store-on-EU-s-antitrust-radar.html', 'domain': 'kitco.com', 'published_date': '2020-08-10 18:01:00', 'lang': 'en'}),
#  Document(page_content='SpaceX Crew-1 mission with NASA, first fully operational crewed mission to space to launch in October', metadata={'topic': 'SCIENCE', 'link': 'https://mybigplunge.com/tech-plunge/spacex-crew-1-mission-with-nasa-first-fully-operational-crewed-mission-to-space-to-launch-in-october/', 'domain': 'mybigplunge.com', 'published_date': '2020-08-17 00:03:42', 'lang': 'en'}),
#  Document(page_content='UFC 4: Official soundtrack released as Spotify playlist – Eminem, J Cole, MGK and more', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.hitc.com/en-gb/2020/08/06/ufc-4-official-soundtrack-on-spotify/', 'domain': 'hitc.com', 'published_date': '2020-08-06 17:22:00', 'lang': 'en'}),
#  Document(page_content="The Switch is officially Nintendo's second best selling console ever", metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.kitguru.net/gaming/mustafa-mahmoud/the-switch-is-officially-nintendos-second-best-selling-console-ever/', 'domain': 'kitguru.net', 'published_date': '2020-08-17 10:46:06', 'lang': 'en'}),
#  Document(page_content='The Difference Between Success and Failure: (Neuro)science of Getting and Staying Motivated', metadata={'topic': 'TECHNOLOGY', 'link': 'https://scitechdaily.com/the-difference-between-success-and-failure-neuroscience-of-getting-and-staying-motivated/', 'domain': 'scitechdaily.com', 'published_date': '2020-08-15 23:04:07', 'lang': 'en'}),
#  Document(page_content='Toshiba shuts the lid on laptops after 35 years', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.myjoyonline.com/business/technology-business/toshiba-shuts-the-lid-on-laptops-after-35-years/', 'domain': 'myjoyonline.com', 'published_date': '2020-08-10 12:27:56', 'lang': 'en'}),
#  Document(page_content='The phone camera is king and the Note 20 Ultra wears the crown…for now', metadata={'topic': 'TECHNOLOGY', 'link': 'https://sea.mashable.com/tech/11984/the-phone-camera-is-king-and-the-note-20-ultra-wears-the-crownfor-now', 'domain': 'sea.mashable.com', 'published_date': '2020-08-17 05:08:00', 'lang': 'en'}),
#  Document(page_content='Asteroid 29075 1950 DA would be the greatest catastrophe for Earth, Tsunami of 400 toes excessive waves', metadata={'topic': 'SCIENCE', 'link': 'https://pledgetimes.com/asteroid-29075-1950-da-would-be-the-greatest-catastrophe-for-earth-tsunami-of-400-toes-excessive-waves/', 'domain': 'pledgetimes.com', 'published_date': '2020-08-07 11:06:50', 'lang': 'en'}),
#  Document(page_content='Fall Guys Is Giving Free Gifts To Anyone Who Has Opened The Game Before Tomorrow Morning', metadata={'topic': 'TECHNOLOGY', 'link': 'https://press-start.com.au/news/playstation/2020/08/13/fall-guys-is-giving-free-gifts-to-anyone-who-has-opened-the-game-before-tomorrow-morning/', 'domain': 'press-start.com.au', 'published_date': '2020-08-13 12:25:10', 'lang': 'en'}),
#  Document(page_content='ATLAS Space Operations Awarded NASA SBIR Phase II Award to Advance Satellite Constellation Management Scheduling', metadata={'topic': 'SCIENCE', 'link': 'http://spaceref.com/news/viewpr.html?pid=56068', 'domain': 'spaceref.com', 'published_date': '2020-08-03 23:01:12', 'lang': 'en'}),
#  Document(page_content='Xiaomi patents a phone with a detachable display', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.gizchina.com/2020/08/04/xiaomi-patents-a-phone-with-a-detachable-display/', 'domain': 'gizchina.com', 'published_date': '2020-08-04 10:07:41', 'lang': 'en'}),
#  Document(page_content='Greenland Ice Melting Now Irreversible, Has Passed "Tipping Point": Study', metadata={'topic': 'SCIENCE', 'link': 'https://www.ndtv.com/world-news/greenland-ice-glaciers-melting-past-tipping-point-amid-climate-change-study-2280983', 'domain': 'ndtv.com', 'published_date': '2020-08-17 17:14:35', 'lang': 'en'}),
#  Document(page_content='Call of Duty Modern Warfare and Warzone Season 5 update 1.24 LIVE on PlayStation 4', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.express.co.uk/entertainment/gaming/1318052/Call-of-Duty-Modern-Warfare-Warzone-Season-5-update-1-24-PlayStation-4-file-size-pre-load', 'domain': 'express.co.uk', 'published_date': '2020-08-04 00:20:00', 'lang': 'en'}),
#  Document(page_content="Bell Launches 'Streamer' Android TV Box; Fibe TV Gets Prime Video App", metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.iphoneincanada.ca/carriers/bell/bell-streamer-android-tv-box-prime-video/', 'domain': 'iphoneincanada.ca', 'published_date': '2020-08-04 14:57:53', 'lang': 'en'}),
#  Document(page_content='Xiaomi celebrates 10th anniversary with flagship Mi 10 Ultra', metadata={'topic': 'TECHNOLOGY', 'link': 'https://techcentral.co.za/xiaomi-celebrates-10th-anniversary-with-flagship-mi-10-ultra/100379/', 'domain': 'techcentral.co.za', 'published_date': '2020-08-11 15:59:00', 'lang': 'en'}),
#  Document(page_content="Apple's John Giannandrea talks Apple Silicon, moving from Google to Apple", metadata={'topic': 'TECHNOLOGY', 'link': 'https://appleinsider.com/articles/20/08/06/apples-john-giannandrea-talks-apple-silicon-moving-from-google-to-apple-in-interview', 'domain': 'appleinsider.com', 'published_date': '2020-08-06 12:51:15', 'lang': 'en'}),
#  Document(page_content='Xbox Series X will release no later than November 13, based on this listing', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.techradar.com/nz/news/xbox-series-x-will-release-no-later-than-november-13-based-on-this-listing', 'domain': 'techradar.com', 'published_date': '2020-08-13 10:30:00', 'lang': 'en'}),
#  Document(page_content='Call of Duty: Warzone Player Tricks Enemy By Playing Dead', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.gamespot.com/articles/call-of-duty-warzone-player-tricks-enemy-by-playin/1100-6480720/', 'domain': 'gamespot.com', 'published_date': '2020-08-09 17:22:00', 'lang': 'en'}),
#  Document(page_content='NASA Astronauts in SpaceX Capsule Splashdown in Gulf Of Mexico', metadata={'topic': 'SCIENCE', 'link': 'https://www.thequint.com/news/world/nasa-astronauts-in-spacex-capsule-make-touchdow-in-in-gulf-of-mexico', 'domain': 'thequint.com', 'published_date': '2020-08-03 03:02:32', 'lang': 'en'}),
#  Document(page_content='Google Maps Finally Found its Way Back to the Apple Watch', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.gizmodo.co.uk/2020/08/google-maps-finally-found-its-way-back-to-the-apple-watch/', 'domain': 'gizmodo.co.uk', 'published_date': '2020-08-11 15:00:00', 'lang': 'en'}),
#  Document(page_content="Rockstar Games Rolls Back Unplayable 'Red Dead Online' Patch", metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.ibtimes.com/rockstar-games-rolls-back-unplayable-red-dead-online-patch-3028298', 'domain': 'ibtimes.com', 'published_date': '2020-08-14 05:50:56', 'lang': 'en'}),
#  Document(page_content="Beck teams up with NASA and AI for 'Hyperspace' visual album experience", metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.space.com/beck-nasa-hyperspace-ai-visual-album-experience.html', 'domain': 'space.com', 'published_date': '2020-08-12 19:56:00', 'lang': 'en'}),
#  Document(page_content='The Galaxy Note 20 doesn’t ship with AKG earbuds in the US, but you can ask for them', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.xda-developers.com/samsung-galaxy-note-20-free-usb-c-earbuds-us/', 'domain': 'xda-developers.com', 'published_date': '2020-08-17 21:26:00', 'lang': 'en'}),
#  Document(page_content='Blasphemous gets a new storyline, New Game Plus and more for free', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.pcgamer.com/au/blasphemous-gets-a-new-storyline-new-game-plus-and-more-for-free/', 'domain': 'pcgamer.com', 'published_date': '2020-08-04 13:33:00', 'lang': 'en'}),
#  Document(page_content='Alien base on Mercury: ET hunters claim to find huge UFO', metadata={'topic': 'SCIENCE', 'link': 'https://www.express.co.uk/news/weird/1323720/alien-base-ufo-mercury-space-news-conspiracy-theory-aliens', 'domain': 'express.co.uk', 'published_date': '2020-08-17 08:39:37', 'lang': 'en'}),
#  Document(page_content="Australia's small yet crucial part in the mission to find life on Mars", metadata={'topic': 'SCIENCE', 'link': 'https://www.brisbanetimes.com.au/national/australia-s-small-yet-crucial-part-in-the-mission-to-find-life-on-mars-20200803-p55i31.html?ref=rss&utm_medium=rss&utm_source=rss_feed', 'domain': 'brisbanetimes.com.au', 'published_date': '2020-08-03 07:23:00', 'lang': 'en'}),
#  Document(page_content='Xiaomi Mi 10 Ultra and K30 Ultra not coming out of China news', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.gsmarena.com/the_xiaomi_mi_10_ultra_and_k30_ultra_are_china_only-news-44712.php', 'domain': 'gsmarena.com', 'published_date': '2020-08-12 08:59:01', 'lang': 'en'}),
#  Document(page_content="Reaction: Sony Wants PS5 to Be the Best Place to Play, And It'll Open Its Wallet to Achieve It", metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.pushsquare.com/news/2020/08/reaction_sony_wants_ps5_to_be_the_best_place_to_play_and_itll_open_its_wallet_to_achieve_it', 'domain': 'pushsquare.com', 'published_date': '2020-08-04 14:00:00', 'lang': 'en'}),
#  Document(page_content='Science News | Researchers Suggest Osmotic Therapy Device for Spinal Cord Injuries', metadata={'topic': 'SCIENCE', 'link': 'https://www.latestly.com/agency-news/science-news-researchers-suggest-osmotic-therapy-device-for-spinal-cord-injuries-1967445.html', 'domain': 'latestly.com', 'published_date': '2020-08-16 15:17:17', 'lang': 'en'}),
#  Document(page_content="Samsung Galaxy Note 20's claim of 'gender fluidity' ridiculed online", metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.newshub.co.nz/home/lifestyle/2020/08/samsung-galaxy-note-20-s-claim-of-gender-fluidity-ridiculed-online.html', 'domain': 'newshub.co.nz', 'published_date': '2020-08-06 02:56:08', 'lang': 'en'}),
#  Document(page_content='Music is big on Twitch. Now record labels want it to pay up', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.cnn.com/2020/08/14/tech/twitch-record-dmca-copyright-notices/index.html', 'domain': 'cnn.com', 'published_date': '2020-08-14 10:23:00', 'lang': 'en'}),
#  Document(page_content='iPhone 12 series could launch in October; on this date', metadata={'topic': 'TECHNOLOGY', 'link': 'https://indianexpress.com/article/technology/mobile-tabs/iphone-12-launch-date-october-6552964/', 'domain': 'indianexpress.com', 'published_date': '2020-08-13 08:23:54', 'lang': 'en'}),
#  Document(page_content="Sleep Check app asks 'Is there more to your snore'?", metadata={'topic': 'TECHNOLOGY', 'link': 'https://mumbrella.com.au/sleep-check-app-asks-is-there-more-to-your-snore-638401', 'domain': 'mumbrella.com.au', 'published_date': '2020-08-12 00:27:31', 'lang': 'en'}),
#  Document(page_content='11 Best Cooling Face Masks for Summer 2020', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.menshealth.com/technology-gear/g33545606/cooling-face-masks/', 'domain': 'menshealth.com', 'published_date': '2020-08-07 15:44:00', 'lang': 'en'}),
#  Document(page_content='Tales of Runeterra “The Vaulted Road” teases future LoR champions', metadata={'topic': 'TECHNOLOGY', 'link': 'https://dotesports.com/lor/news/tales-of-runeterra-the-vaulted-road-teases-future-lor-champions', 'domain': 'dotesports.com', 'published_date': '2020-08-11 16:20:00', 'lang': 'en'}),
#  Document(page_content='Alexa helps players navigate sci-fi world in first 3 episodes of Amazon audio adventure ‘Starfinder’', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.geekwire.com/2020/alexa-helps-players-navigate-sci-fi-world-first-3-episodes-amazon-audio-adventure-starfinder/', 'domain': 'geekwire.com', 'published_date': '2020-08-04 14:00:00', 'lang': 'en'}),
#  Document(page_content='Samsung Galaxy Note 20 vs. iPhone 11 Pro: A Galaxy of competition', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.digitaltrends.com/mobile/samsung-galaxy-note-20-vs-iphone-11-pro/', 'domain': 'digitaltrends.com', 'published_date': '2020-08-12 15:14:00', 'lang': 'en'}),
#  Document(page_content='Nintendo profit soars as people play more games staying home during the pandemic', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.deccanchronicle.com/technology/in-other-news/060820/nintendo-profit-soars-as-people-play-more-games-staying-home-during-th.html', 'domain': 'deccanchronicle.com', 'published_date': '2020-08-06 15:11:00', 'lang': 'en'}),
#  Document(page_content='Xbox Series S Reportedly Confirmed by Controller Packaging Leak', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.digitalmarketnews.com/xbox-series-s-reportedly-confirmed-by-controller-packaging-leak/', 'domain': 'digitalmarketnews.com', 'published_date': '2020-08-10 01:51:00', 'lang': 'en'}),
#  Document(page_content='Leaked renders reveal Samsung Galaxy S20 FE', metadata={'topic': 'TECHNOLOGY', 'link': 'https://mobilesyrup.com/2020/08/17/leaked-renders-reveal-samsung-galaxy-s20-fe/', 'domain': 'mobilesyrup.com', 'published_date': '2020-08-17 19:34:00', 'lang': 'en'}),
#  Document(page_content='Intel 11th-gen CPU launch date revealed', metadata={'topic': 'TECHNOLOGY', 'link': 'https://mybroadband.co.za/news/hardware/363086-intel-11th-gen-cpu-launch-date-revealed.html', 'domain': 'mybroadband.co.za', 'published_date': '2020-08-07 06:46:41', 'lang': 'en'}),
#  Document(page_content='EV West Is Going for an Electric Speed Record at Bonneville Using Tesla Power', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.autoevolution.com/news/ev-west-is-going-for-an-electric-speed-record-at-bonneville-using-tesla-power-146902.html', 'domain': 'autoevolution.com', 'published_date': '2020-08-04 10:05:00', 'lang': 'en'}),
#  Document(page_content='Nreal Light AR glasses launch bundled with Galaxy Note 20 5G', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.slashgear.com/nreal-light-ar-glasses-launch-bundled-with-galaxy-note-20-5g-10632842/', 'domain': 'slashgear.com', 'published_date': '2020-08-11 04:01:00', 'lang': 'en'}),
#  Document(page_content="Long-time Mac developer's apps pulled from Mac App Store because of automated system failure", metadata={'topic': 'TECHNOLOGY', 'link': 'https://appleinsider.com/articles/20/08/04/apple-kills-long-time-mac-developers-apps-with-no-warning-and-isnt-responding', 'domain': 'appleinsider.com', 'published_date': '2020-08-04 20:39:37', 'lang': 'en'}),
#  Document(page_content='Kids Helpline says demand in Victoria for its counselling service rose 8% in July', metadata={'topic': 'SCIENCE', 'link': 'https://www.theguardian.com/australia-news/2020/aug/05/kids-helpline-says-demand-in-victoria-for-its-counselling-service-rose-8-in-july', 'domain': 'theguardian.com', 'published_date': '2020-08-04 17:30:00', 'lang': 'en'}),
#  Document(page_content="Intel to Launch 'Xe HPG' PC Gaming Graphics Cards in 2021, Using Outside Foundry", metadata={'topic': 'TECHNOLOGY', 'link': 'https://au.pcmag.com/graphic-cards/68095/intel-to-launch-xe-hpg-pc-gaming-graphics-cards-in-2021-using-outside-foundry', 'domain': 'au.pcmag.com', 'published_date': '2020-08-13 13:08:00', 'lang': 'en'}),
#  Document(page_content='Russia gearing up to launch moon mission in 2021', metadata={'topic': 'SCIENCE', 'link': 'https://www.space.com/russia-moon-mission-luna-25.html', 'domain': 'space.com', 'published_date': '2020-08-07 18:00:00', 'lang': 'en'}),
#  Document(page_content='Maserati unveils Trofeo super sedans', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.businesslive.co.za/bd/life/motoring/2020-08-13-maserati-unveils-trofeo-super-sedans/', 'domain': 'businesslive.co.za', 'published_date': '2020-08-13 03:05:00', 'lang': 'en'}),
#  Document(page_content='Ghostwire: Tokyo confirms dog petting', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.gematsu.com/2020/08/ghostwire-tokyo-confirms-dog-petting', 'domain': 'gematsu.com', 'published_date': '2020-08-07 16:43:13', 'lang': 'en'}),
#  Document(page_content='Insect can escape after being eaten by frog, scientists find', metadata={'topic': 'SCIENCE', 'link': 'https://thenationonlineng.net/insect-can-escape-after-being-eaten-by-frog-scientists-find/', 'domain': 'thenationonlineng.net', 'published_date': '2020-08-03 18:06:18', 'lang': 'en'}),
#  Document(page_content='Quibi Tests a Free Version in Australia and New Zealand', metadata={'topic': 'TECHNOLOGY', 'link': 'https://matzavreview.com/2020/08/07/quibi-tests-a-free-version-in-australia-and-new-zealand/', 'domain': 'matzavreview.com', 'published_date': '2020-08-07 18:40:00', 'lang': 'en'}),
#  Document(page_content='Huawei teases the new MateBook X Pro for August 19 news', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.gsmarena.com/huawei_teases_the_new_matebook_x_pro_for_august_19-news-44772.php', 'domain': 'gsmarena.com', 'published_date': '2020-08-17 11:40:01', 'lang': 'en'}),
#  Document(page_content='The Last of Us 2 Factions multiplayer gameplay footage leaks online', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.gamesradar.com/the-last-of-us-2-factions-multiplayer-gameplay-leak/', 'domain': 'gamesradar.com', 'published_date': '2020-08-06 09:20:00', 'lang': 'en'}),
#  Document(page_content='Tonight offers best chance of spotting space station in night sky', metadata={'topic': 'SCIENCE', 'link': 'https://www.pennlive.com/life/2020/08/tonight-offers-best-chance-of-spotting-space-station-in-night-sky.html', 'domain': 'pennlive.com', 'published_date': '2020-08-03 21:55:00', 'lang': 'en'}),
#  Document(page_content='How to take a screenshot on Google Chrome in 4 ways', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.businessinsider.com/how-to-screenshot-on-google-chrome', 'domain': 'businessinsider.com', 'published_date': '2020-08-03 20:05:30', 'lang': 'en'}),
#  Document(page_content='Get more than 20 free PC games this month with the new Amazon Prime Gaming', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.asiaone.com/digital/get-more-20-free-pc-games-month-new-amazon-prime-gaming', 'domain': 'asiaone.com', 'published_date': '2020-08-12 01:43:09', 'lang': 'en'}),
#  Document(page_content='Wearing of face masks in retail settings becomes mandatory from today', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.irishexaminer.com/news/arid-40030037.html', 'domain': 'irishexaminer.com', 'published_date': '2020-08-10 06:24:00', 'lang': 'en'}),
#  Document(page_content='Galaxy Watch 3: All the fitness features Samsung promised for its next smartwatch', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.digitalmarketnews.com/galaxy-watch-3-all-the-fitness-features-samsung-promised-for-its-next-smartwatch/', 'domain': 'digitalmarketnews.com', 'published_date': '2020-08-08 09:16:00', 'lang': 'en'}),
#  Document(page_content='Dishonored Co-Director Explains Why He Left Arkane To Go Indie', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.gamespot.com/articles/dishonored-co-director-explains-why-he-left-arkane/1100-6480793/', 'domain': 'gamespot.com', 'published_date': '2020-08-11 01:33:00', 'lang': 'en'}),
#  Document(page_content="Fortnite is still available at Samsung's Galaxy Store news", metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.gsmarena.com/fortnite_is_still_available_at_samsungs_galaxy_store-news-44748.php', 'domain': 'gsmarena.com', 'published_date': '2020-08-14 12:57:01', 'lang': 'en'}),
#  Document(page_content='Major Apple leak reveals release dates for next TWO iPhones, iPads and Apple Watches', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.thesun.co.uk/tech/12400142/iphone-12-release-date-apple-watch-ipad-september-october-2020-leak/', 'domain': 'thesun.co.uk', 'published_date': '2020-08-14 09:41:00', 'lang': 'en'}),
#  Document(page_content="New Guinea named world's most plant-rich island", metadata={'topic': 'SCIENCE', 'link': 'https://www.miragenews.com/new-guinea-named-world-s-most-plant-rich-island/', 'domain': 'miragenews.com', 'published_date': '2020-08-07 03:03:25', 'lang': 'en'}),
#  Document(page_content="RACHEL SHENK: Meteor shower is reminder of nature's beauty", metadata={'topic': 'SCIENCE', 'link': 'https://www.goshennews.com/news/rachel-shenk-meteor-shower-is-reminder-of-natures-beauty/article_4059dc3c-dff4-11ea-87c6-8b5d11275614.html', 'domain': 'goshennews.com', 'published_date': '2020-08-17 02:15:00', 'lang': 'en'}),
#  Document(page_content='Scientists Have Discovered How To Extract Rare Earth Elements From Acid Mine Drainage', metadata={'topic': 'TECHNOLOGY', 'link': 'https://cleantechnica.com/2020/08/14/scientists-have-discovered-how-to-extract-rare-earth-elements-from-acid-mine-drainage/', 'domain': 'cleantechnica.com', 'published_date': '2020-08-15 03:41:13', 'lang': 'en'}),
#  Document(page_content='Final Fantasy XVI Will Have Some Kind of Playstation 5 Exclusivity; Game Was Supposed to Be Revealed in June – Rumor', metadata={'topic': 'TECHNOLOGY', 'link': 'https://wccftech.com/final-fantasy-xvi-playstation-5-exclusivity/', 'domain': 'wccftech.com', 'published_date': '2020-08-04 12:02:34', 'lang': 'en'}),
#  Document(page_content="Facebook blames Apple's App Store policies for launching incomplete Facebook Gaming on iOS", metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.techspot.com/news/86290-facebook-blames-apple-app-store-policies-launching-incomplete.html', 'domain': 'techspot.com', 'published_date': '2020-08-07 21:49:00', 'lang': 'en'}),
#  Document(page_content='Lenovo and HP control half of the global laptop market', metadata={'topic': 'TECHNOLOGY', 'link': 'https://phonemantra.com/lenovo-and-hp-control-half-of-the-global-laptop-market/', 'domain': 'phonemantra.com', 'published_date': '2020-08-14 05:43:00', 'lang': 'en'}),
#  Document(page_content='The Majestic Valleys of Mars May Not Have Been Carved by Rivers After All', metadata={'topic': 'SCIENCE', 'link': 'https://techtoday19.com/nz/the-majestic-valleys-of-mars-may-not-have-been-carved-by-rivers-after-all/', 'domain': 'techtoday19.com', 'published_date': '2020-08-04 03:35:49', 'lang': 'en'}),
#  Document(page_content='#FossilFriday: Amazing 429 million-year-old trilobite eye saw the world like modern insects', metadata={'topic': 'SCIENCE', 'link': 'https://www.zmescience.com/science/news-science/fossilfriday-amazing-429-million-year-old-trilobite-eye-saw-the-world-like-modern-insects/', 'domain': 'zmescience.com', 'published_date': '2020-08-14 14:56:18', 'lang': 'en'}),
#  Document(page_content='EA Sports outline changes made in ‘FIFA 21’ career mode', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.nme.com/news/gaming-news/ea-sports-outline-changes-made-in-fifa-21-career-mode-2727314', 'domain': 'nme.com', 'published_date': '2020-08-13 19:04:00', 'lang': 'en'}),
#  Document(page_content='10 Brilliant Video Games That Surprised Everyone - Commenter Edition', metadata={'topic': 'TECHNOLOGY', 'link': 'https://whatculture.com/gaming/10-brilliant-video-games-that-surprised-everyone-commenter-edition', 'domain': 'whatculture.com', 'published_date': '2020-08-09 08:02:44', 'lang': 'en'}),
#  Document(page_content='SpaceX brings NASA astronauts safely home', metadata={'topic': 'SCIENCE', 'link': 'https://themalaysianreserve.com/2020/08/04/spacex-brings-nasa-astronauts-safely-home/', 'domain': 'themalaysianreserve.com', 'published_date': '2020-08-04 05:37:30', 'lang': 'en'}),
#  Document(page_content='How to use Microsoft Teams with your friends and family', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.theverge.com/21349783/microsoft-teams-texting-calls-videoconferencing-how-to', 'domain': 'theverge.com', 'published_date': '2020-08-07 12:00:00', 'lang': 'en'}),
#  Document(page_content='Avengers: 8 Ways To Save The Game', metadata={'topic': 'TECHNOLOGY', 'link': 'https://whatculture.com/gaming/avengers-8-ways-to-save-the-game', 'domain': 'whatculture.com', 'published_date': '2020-08-17 16:22:07', 'lang': 'en'}),
#  Document(page_content='OnePlus Nord Open Sale Delayed to August 6 Due to ‘Unprecedented Demand During Pre-Order’', metadata={'topic': 'TECHNOLOGY', 'link': 'https://gadgets.ndtv.com/mobiles/news/oneplus-nord-sale-delay-august-6-india-unprecedented-demand-during-pre-order-2273758', 'domain': 'gadgets.ndtv.com', 'published_date': '2020-08-04 05:33:57', 'lang': 'en'}),
#  Document(page_content='Apple iPad Air 2020: New Report Suggests Dramatic Feature Change', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.forbes.com/sites/davidphelan/2020/08/08/apple-ipad-air-2020-new-report-suggests-dramatic-feature-change/', 'domain': 'forbes.com', 'published_date': '2020-08-08 18:36:00', 'lang': 'en'}),
#  Document(page_content='BMW X3 M SUV Resumes Testing Ahead of Launch in India', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.rushlane.com/bmw-x3-m-suv-resumes-testing-12370605.html', 'domain': 'rushlane.com', 'published_date': '2020-08-09 15:27:00', 'lang': 'en'}),
#  Document(page_content='Call of Duty Warzone’s Black Ops treasure hunt continued this weekend', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.videogameschronicle.com/news/call-of-duty-warzones-black-ops-treasure-hunt-continued-this-weekend/', 'domain': 'videogameschronicle.com', 'published_date': '2020-08-16 13:03:00', 'lang': 'en'}),
#  Document(page_content='Always On Feature with Google Pixel Watch', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.core77.com/projects/101208/Always-On-Feature-with-Google-Pixel-Watch?utm_source=public_sidebar', 'domain': 'core77.com', 'published_date': '2020-08-11 14:20:10', 'lang': 'en'}),
#  Document(page_content='Special Aston Martins get ski rack, self-destruct button', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.autocar.co.nz/autocar-news-app/special-aston-martins-get-ski-rack-self-destruct-button', 'domain': 'autocar.co.nz', 'published_date': '2020-08-17 01:42:00', 'lang': 'en'}),
#  Document(page_content='Apple updates 27-inch iMac with faster processors, SSDs, and nano-texture display', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.reporter.am/apple-updates-27-inch-imac-with-faster-processors-ssds-and-nano-texture-display/', 'domain': 'reporter.am', 'published_date': '2020-08-04 23:18:00', 'lang': 'en'}),
#  Document(page_content="Apple's Antitrust battles - The story so far", metadata={'topic': 'TECHNOLOGY', 'link': 'https://appleinsider.com/articles/20/08/15/apples-antitrust-battles---the-story-so-far', 'domain': 'appleinsider.com', 'published_date': '2020-08-15 22:34:26', 'lang': 'en'}),
#  Document(page_content='Why COVID-19 poses a special risk during pregnancy, and how hair can split steel', metadata={'topic': 'SCIENCE', 'link': 'https://www.sciencemag.org/podcast/why-covid-19-poses-special-risk-during-pregnancy-and-how-hair-can-split-steel', 'domain': 'sciencemag.org', 'published_date': '2020-08-06 18:00:00', 'lang': 'en'}),
#  Document(page_content='Play Xbox games on your Android: Xbox Game Pass Ultimate beta date revealed', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.techradar.com/news/play-xbox-games-on-your-android-xbox-game-pass-ultimate-beta-date-revealed', 'domain': 'techradar.com', 'published_date': '2020-08-04 14:10:00', 'lang': 'en'}),
#  Document(page_content='Smartphone shipments in China plunge 35 per cent in July: government data', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.standardmedia.co.ke/sci-tech/article/2001382224/smartphone-shipments-in-china-plunge-35-per-cent-in-july', 'domain': 'standardmedia.co.ke', 'published_date': '2020-08-12 08:46:09', 'lang': 'en'}),
#  Document(page_content='ZTE Axon A20 5G pictures and specs have been revealed', metadata={'topic': 'TECHNOLOGY', 'link': 'https://digistatement.com/zte-axon-a20-5g-pictures-and-specs-have-been-revealed/', 'domain': 'digistatement.com', 'published_date': '2020-08-14 11:09:46', 'lang': 'en'}),
#  Document(page_content='Perseid meteor shower 2020: How and when to watch', metadata={'topic': 'SCIENCE', 'link': 'https://tucson.com/news/world/perseid-meteor-shower-2020-how-and-when-to-watch/article_88664df7-f9cc-545d-aca0-59e691aa40a8.html', 'domain': 'tucson.com', 'published_date': '2020-08-11 16:58:44', 'lang': 'en'}),
#  Document(page_content='Someone In Australia Is Selling A Ferrari 360 Modena Limo For AU$399,999', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.carscoops.com/2020/08/someone-in-australia-is-selling-a-ferrari-360-modena-limo-for-au399999/', 'domain': 'carscoops.com', 'published_date': '2020-08-04 00:30:00', 'lang': 'en'}),
#  Document(page_content='Call of Duty: Warzone Season 5 Trailer Reveals New Areas and a Train', metadata={'topic': 'TECHNOLOGY', 'link': 'https://collider.com/call-of-duty-season-5-trailer/', 'domain': 'collider.com', 'published_date': '2020-08-03 20:54:14', 'lang': 'en'}),
#  Document(page_content="Juha Saarinen: Don't let kids hack their way into prison", metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.nzherald.co.nz/business/news/article.cfm?c_id=3&objectid=12353674', 'domain': 'nzherald.co.nz', 'published_date': '2020-08-04 17:02:07', 'lang': 'en'}),
#  Document(page_content='Acer Swift 3 featuring a 10th-generation Intel Ice Lake CPU, 2K screen, and more launched in India for INR 64999 (US$865)', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.notebookcheck.net/Acer-Swift-3-featuring-a-10th-generation-Intel-Ice-Lake-CPU-2K-screen-and-more-launched-in-India-for-INR-64-999-US-865.484132.0.html', 'domain': 'notebookcheck.net', 'published_date': '2020-08-05 09:13:03', 'lang': 'en'}),
#  Document(page_content='NASA Saved Its Mars Mole, Is It True?', metadata={'topic': 'SCIENCE', 'link': 'https://worldtoptrend.com/2020/08/nasa-saved-its-mars-mole-is-it-true/', 'domain': 'worldtoptrend.com', 'published_date': '2020-08-15 16:45:00', 'lang': 'en'}),
#  Document(page_content='Porsche 911 Turbo S versus McLaren 720S in drag race', metadata={'topic': 'TECHNOLOGY', 'link': 'https://m.drive.com.au/news/porsche-911-turbo-s-versus-mclaren-720s-in-drag-race-124031', 'domain': 'm.drive.com.au', 'published_date': '2020-08-10 03:29:49', 'lang': 'en'}),
#  Document(page_content="Intel's plans for gamers in focus: Tiger Lake and Xe graphics are coming soon", metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.eurogamer.net/articles/digitalfoundry-2020-intel-architecture-day-tiger-lake-xe-gaming-focus', 'domain': 'eurogamer.net', 'published_date': '2020-08-13 13:04:00', 'lang': 'en'}),
#  Document(page_content="OPPO's 10000mAh Power Bank 2 with 12-factor safety assurance is coming to India", metadata={'topic': 'TECHNOLOGY', 'link': 'https://pocketnow.com/oppos-10000mah-power-bank-2-with-12-factor-safety-assurance-is-coming-to-india', 'domain': 'pocketnow.com', 'published_date': '2020-08-17 11:00:00', 'lang': 'en'}),
#  Document(page_content='New CT scanning method may improve heart massage', metadata={'topic': 'SCIENCE', 'link': 'https://www.dotmed.com/news/story/52115', 'domain': 'dotmed.com', 'published_date': '2020-08-07 15:38:06', 'lang': 'en'}),
#  Document(page_content='Brazilian Gaming Company Reaches $3 Billion Valuation With New Investment', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.nytimes.com/reuters/2020/08/14/business/14reuters-brazil-unicorn.html', 'domain': 'nytimes.com', 'published_date': '2020-08-14 20:21:00', 'lang': 'en'}),
#  Document(page_content='Video Fire Detection: How it Works (Technology and Equipment)', metadata={'topic': 'SCIENCE', 'link': 'https://nerdsmagazine.com/video-fire-detection-how-it-works-technology-and-equipment/', 'domain': 'nerdsmagazine.com', 'published_date': '2020-08-17 10:43:00', 'lang': 'en'}),
# ...
#  Document(page_content='Why HPV Tests Preferred to Pap Smears for Cervical Cancer Screening', metadata={'topic': 'HEALTH', 'link': 'https://www.healthline.com/health-news/hpv-tests-may-be-preferable-to-pap-smears-cervical-cancer-screening', 'domain': 'healthline.com', 'published_date': '2020-08-05 22:49:53', 'lang': 'en'}),
#  Document(page_content='Alleged NVIDIA GeForce RTX 3090 Images Point To 24GB GDDR6X RAM, PCIe 4.0 Interface', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.lowyat.net/2020/219256/alleged-nvidia-geforce-rtx-3090-could-feature-up-to-24gb-gddr6x-ram-pcie-4-0-interface/', 'domain': 'lowyat.net', 'published_date': '2020-08-15 12:35:32', 'lang': 'en'}),
#  Document(page_content="Ubisoft's Ashraf Ismail fired following misconduct investigation", metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.gamesindustry.biz/articles/2020-08-14-ubisofts-ashraf-ismail-fired-following-misconduct-investigation', 'domain': 'gamesindustry.biz', 'published_date': '2020-08-14 13:39:07', 'lang': 'en'}),
#  Document(page_content='Drinking in pubs creates "perfect storm" for spreading coronavirus', metadata={'topic': 'HEALTH', 'link': 'https://www.sciencefocus.com/news/drinking-in-pubs-creates-perfect-storm-for-spreading-coronavirus/', 'domain': 'sciencefocus.com', 'published_date': '2020-08-10 09:13:00', 'lang': 'en'}),
#  Document(page_content='Broken cable tears 100-foot hole in Arecibo Observatory in Puerto Rico', metadata={'topic': 'SCIENCE', 'link': 'https://www.businessinsider.com/broken-cable-tears-100-foot-hole-in-arecibo-observatory-2020-8', 'domain': 'businessinsider.com', 'published_date': '2020-08-10 07:00:00', 'lang': 'en'}),
#  Document(page_content='What Scientists Know About Airborne Transmission of the New Coronavirus', metadata={'topic': 'HEALTH', 'link': 'https://www.redlakenationnews.com/story/2020/08/13/news/what-scientists-know-about-airborne-transmission-of-the-new-coronavirus/91438.html', 'domain': 'redlakenationnews.com', 'published_date': '2020-08-13 05:44:30', 'lang': 'en'}),
#  Document(page_content='Another Cyberpunk 2077 Presentation Is Happening Tonight', metadata={'topic': 'TECHNOLOGY', 'link': 'https://press-start.com.au/news/playstation/2020/08/10/another-cyberpunk-2077-presentation-is-happening/', 'domain': 'press-start.com.au', 'published_date': '2020-08-10 05:33:05', 'lang': 'en'}),
#  Document(page_content='Over 50 percent of console fighting game players use Wi-Fi for online matches according to Katsuhiro Harada', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.eventhubs.com/news/2020/aug/02/over-50-percent-console-fighting-game-players-use-wi-fi-online-matches-according-katsuhiro-harada/', 'domain': 'eventhubs.com', 'published_date': '2020-08-02 16:53:48', 'lang': 'en'}),
#  Document(page_content='Browser privacy: Change these settings now, whether you use Chrome, Safari or Firefox', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.cnet.com/how-to/browser-privacy-change-these-settings-now-whether-you-use-chrome-safari-or-firefox/', 'domain': 'cnet.com', 'published_date': '2020-08-06 11:30:02', 'lang': 'en'}),
#  Document(page_content='Soviet Bioshock-like Atomic Heart shows off boss fight gameplay in this new video', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.pcgamesn.com/atomic-heart/plyush-boss-fight', 'domain': 'pcgamesn.com', 'published_date': '2020-08-12 16:55:00', 'lang': 'en'}),
#  Document(page_content='Freebie alert: Amazon is giving away 5 video games (worth nearly $100) to all Prime members', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.yahoo.com/entertainment/twitch-prime-august-free-games-172650286.html', 'domain': 'yahoo.com', 'published_date': '2020-08-03 17:26:00', 'lang': 'en'}),
#  Document(page_content="NASA data helps uncover our solar system's shape", metadata={'topic': 'SCIENCE', 'link': 'https://www.nanowerk.com/news2/space/newsid=55833.php', 'domain': 'nanowerk.com', 'published_date': '2020-08-05 15:59:52', 'lang': 'en'}),
#  Document(page_content='Flight to Mars to cut cosmonauts’ lifespan by 2.5 years, says report', metadata={'topic': 'SCIENCE', 'link': 'https://tass.com/science/1035264', 'domain': 'tass.com', 'published_date': '2019-06-16 07:38:37', 'lang': 'en'}),
#  Document(page_content="Scientists unlock Alpine trees' molecular defence", metadata={'topic': 'SCIENCE', 'link': 'https://www.bbc.co.uk/news/science-environment-53805399', 'domain': 'bbc.co.uk', 'published_date': '2020-08-17 11:04:13', 'lang': 'en'}),
#  Document(page_content='Apple says cloud gaming apps like Google Stadia violate iOS app store rules', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.digitaltrends.com/gaming/apple-ios-google-stadia-microsoft-xcloud-guidelines-violation/', 'domain': 'digitaltrends.com', 'published_date': '2020-08-07 04:32:00', 'lang': 'en'}),
#  Document(page_content='Twitch Prime Changing To ‘Prime Gaming’ Is Likely For One Major Unspoken Reason', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.forbes.com/sites/paultassi/2020/08/10/twitch-prime-changing-to-prime-gaming-is-likely-for-one-major-unspoken-reason/', 'domain': 'forbes.com', 'published_date': '2020-08-10 13:00:00', 'lang': 'en'}),
#  Document(page_content='Nintendo kickstarts campaign to rid reported islands in ‘Animal Crossing: New Horizons’', metadata={'topic': 'TECHNOLOGY', 'link': 'https://micky.com.au/nintendo-kickstarts-campaign-to-rid-reported-islands-in-animal-crossing-new-horizons/', 'domain': 'micky.com.au', 'published_date': '2020-08-03 23:38:00', 'lang': 'en'}),
#  Document(page_content='Storing energy in red bricks', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.eurekalert.org/pub_releases/2020-08/wuis-sei080620.php', 'domain': 'eurekalert.org', 'published_date': '2020-08-11 15:04:06', 'lang': 'en'}),
#  Document(page_content="Intel's Architecture day reveals details on Alder Lake and the Xe HPG GPU", metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.bit-tech.net/news/tech/cpus/intels-architecture-day-reveals-details-on-alder-lake-and-the-xe-hpg-gpu/1/', 'domain': 'bit-tech.net', 'published_date': '2020-08-17 10:00:00', 'lang': 'en'}),
#  Document(page_content='Sony WH-1000XM4 vs Sony WH-1000XM3: is it worth upgrading?', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.techradar.com/news/sony-wh-1000xm4-vs-sony-wh-1000xm3-is-it-worth-upgrading', 'domain': 'techradar.com', 'published_date': '2020-08-06 23:54:00', 'lang': 'en'}),
#  Document(page_content='Ferrari 812 GTO Mule Looks Like a Mad Max Reject', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.autoevolution.com/news/ferrari-812-gto-mule-looks-like-mad-max-reject-147377.html', 'domain': 'autoevolution.com', 'published_date': '2020-08-13 16:44:00', 'lang': 'en'}),
#  Document(page_content='COVID LATEST: 24 cases confirmed in Swindon over the past two days and no deaths at GWH', metadata={'topic': 'HEALTH', 'link': 'https://www.swindonadvertiser.co.uk/news/18653010.24-cases-confirmed-swindon-past-two-days/', 'domain': 'swindonadvertiser.co.uk', 'published_date': '2020-08-14 17:53:00', 'lang': 'en'}),
#  Document(page_content='Photo of the day: the appearance of the smartphone Xiaomi Mi 10 Ultra with 120x zoom', metadata={'topic': 'TECHNOLOGY', 'link': 'https://phonemantra.com/photo-of-the-day-the-appearance-of-the-smartphone-xiaomi-mi-10-ultra-with-120x-zoom/', 'domain': 'phonemantra.com', 'published_date': '2020-08-09 14:08:00', 'lang': 'en'}),
#  Document(page_content="Google finally launches Nearby Share to rival Apple's AirDrop", metadata={'topic': 'TECHNOLOGY', 'link': 'https://au.news.yahoo.com/google-android-nearby-share-specs-availability-160054637.html', 'domain': 'au.news.yahoo.com', 'published_date': '2020-08-04 16:00:00', 'lang': 'en'}),
#  Document(page_content='Sinopharm shares phase 2 data on inactivated COVID-19 vaccine', metadata={'topic': 'HEALTH', 'link': 'https://www.fiercebiotech.com/biotech/sinopharm-shares-phase-2-data-inactivated-covid-19-vaccine', 'domain': 'fiercebiotech.com', 'published_date': '2020-08-14 10:54:00', 'lang': 'en'}),
#  Document(page_content='Researchers explore social behavior of animals toward emerging infectious diseases', metadata={'topic': 'HEALTH', 'link': 'https://www.news-medical.net/news/20200813/Researchers-explore-the-social-behavior-of-animals-towards-emerging-infectious-diseases.aspx', 'domain': 'news-medical.net', 'published_date': '2020-08-13 05:18:00', 'lang': 'en'}),
#  Document(page_content='Alberta to provide COVID-19 update Wednesday afternoon', metadata={'topic': 'HEALTH', 'link': 'https://globalnews.ca/news/7269178/alberta-covid-19-update-august-12/', 'domain': 'globalnews.ca', 'published_date': '2020-08-12 17:38:28', 'lang': 'en'}),
#  Document(page_content='Realme C12 Shines on Geekbench with an Helio P35 Chipset', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.phoneworld.com.pk/realme-c12-shines-on-geekbench-with-an-helio-p35-chipset/', 'domain': 'phoneworld.com.pk', 'published_date': '2020-08-09 08:14:39', 'lang': 'en'}),
#  Document(page_content='Scientists discover stars rich in Phosphorous that might help us explain the origin of life', metadata={'topic': 'SCIENCE', 'link': 'https://www.timesnownews.com/technology-science/article/scientists-discover-stars-rich-in-phosphorous-that-might-help-us-explain-the-origin-of-life/633509', 'domain': 'timesnownews.com', 'published_date': '2020-08-07 11:17:33', 'lang': 'en'}),
#  Document(page_content='COVID-19: Coronavirus leaves girl with ‘completely different personality’', metadata={'topic': 'HEALTH', 'link': 'https://www.news.com.au/lifestyle/health/health-problems/covid19-coronavirus-leaves-girl-with-completely-different-personality/news-story/7f2e2398545a55393be119d1d88cc83a', 'domain': 'news.com.au', 'published_date': '2020-08-06 09:27:40', 'lang': 'en'}),
#  Document(page_content='State confirms another 1,165 cases, 6 new COVID-19 deaths', metadata={'topic': 'HEALTH', 'link': 'https://www.wbay.com/2020/08/08/state-confirms-another-1165-patients-6-new-covid-19-deaths/', 'domain': 'wbay.com', 'published_date': '2020-08-08 19:03:00', 'lang': 'en'}),
#  Document(page_content="Pub owner's bizarre excuse for not following COVID laws", metadata={'topic': 'HEALTH', 'link': 'https://au.news.yahoo.com/pub-owners-bizarre-excuse-for-not-following-covid-laws-102258897.html', 'domain': 'au.news.yahoo.com', 'published_date': '2020-08-12 10:22:00', 'lang': 'en'}),
#  Document(page_content='Clark County among Nevada counties flagged for elevated COVID-19 transmission risk', metadata={'topic': 'HEALTH', 'link': 'https://www.ktnv.com/news/coronavirus/clark-county-among-8-counties-in-nevada-flagged-for-elevated-covid-19-transmission-risk', 'domain': 'ktnv.com', 'published_date': '2020-08-08 05:15:00', 'lang': 'en'}),
#  Document(page_content='Oh No, Earthworm Jim', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.kotaku.com.au/2020/08/oh-no-earthworm-jim/', 'domain': 'kotaku.com.au', 'published_date': '2020-08-11 00:00:00', 'lang': 'en'}),
#  Document(page_content="WHO says 'vaccine nationalism' cannot beat virus", metadata={'topic': 'HEALTH', 'link': 'http://www.theindependentbd.com/post/251349', 'domain': 'theindependentbd.com', 'published_date': '2020-08-07 03:15:02', 'lang': 'en'}),
#  Document(page_content="COVID-19 update for Aug. 17: Here's the latest on coronavirus in B.C.", metadata={'topic': 'HEALTH', 'link': 'https://www.thecragandcanyon.ca/news/local-news/covid-19-update-for-aug-17-heres-the-latest-on-coronavirus-in-b-c/wcm/ff70ab8d-2ea6-49ca-b9b8-ba53d9e8a1b9?video_autoplay=true', 'domain': 'thecragandcanyon.ca', 'published_date': '2020-08-17 15:59:50', 'lang': 'en'}),
#  Document(page_content='NSW records seven new COVID-19 cases', metadata={'topic': 'HEALTH', 'link': 'https://www.cowraguardian.com.au/story/6881033/nsw-records-seven-new-covid-19-cases/?cs=9397', 'domain': 'cowraguardian.com.au', 'published_date': '2020-08-17 05:00:00', 'lang': 'en'}),
#  Document(page_content='Samsung Galaxy Note 20 Series Guaranteed to Get Android 11, Android 12 and Android 13', metadata={'topic': 'TECHNOLOGY', 'link': 'https://techweez.com/2020/08/06/note-20-series-get-android-11-android-12-android-13/', 'domain': 'techweez.com', 'published_date': '2020-08-06 12:33:00', 'lang': 'en'}),
#  Document(page_content='Zoom, Apple get new competition as Telegram launches video calling', metadata={'topic': 'TECHNOLOGY', 'link': 'https://finance.yahoo.com/news/zoom-apple-competition-telegram-launches-155032973.html', 'domain': 'finance.yahoo.com', 'published_date': '2020-08-16 15:50:00', 'lang': 'en'}),
#  Document(page_content='Gboard adds real-time voice transcription and translation', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.xda-developers.com/gboard-real-time-voice-transcription-translation/', 'domain': 'xda-developers.com', 'published_date': '2020-08-11 19:18:00', 'lang': 'en'}),
#  Document(page_content='Popular Wigan tapas restaurant forced to temporarily shut over Covid outbreak', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.manchestereveningnews.co.uk/news/popular-wigan-tapas-restaurant-forced-18770433', 'domain': 'manchestereveningnews.co.uk', 'published_date': '2020-08-14 13:42:00', 'lang': 'en'}),
#  Document(page_content="NASA's Ingenuity Mars Helicopter Recharges Its Batteries in Flight", metadata={'topic': 'SCIENCE', 'link': 'http://spaceref.com/news/viewpr.html?pid=56116', 'domain': 'spaceref.com', 'published_date': '2020-08-13 23:20:04', 'lang': 'en'}),
#  Document(page_content='Apple Arcade puzzler ‘Grindstone’ drops massive update', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.scmp.com/yp/discover/entertainment/tech-gaming/article/3096917/apple-arcade-puzzler-grindstone-drops-massive', 'domain': 'scmp.com', 'published_date': '2020-08-11 09:06:35', 'lang': 'en'}),
#  Document(page_content='US disease outbreak: CDC issue warning about life-threatening bug that targets children', metadata={'topic': 'HEALTH', 'link': 'https://www.express.co.uk/news/world/1319830/US-disease-acute-flaccid-myelitis-AFM-targets-children-CDC-warning', 'domain': 'express.co.uk', 'published_date': '2020-08-07 08:34:00', 'lang': 'en'}),
#  Document(page_content='The UK is laying off 6,000 workers on its contact tracing scheme after reports detailed how they spent weeks watching Netflix', metadata={'topic': 'HEALTH', 'link': 'https://www.businessinsider.co.za/uk-firing-6000-contact-tracers-reports-bored-quizzing-netflix-2020-8', 'domain': 'businessinsider.co.za', 'published_date': '2020-08-11 11:53:34', 'lang': 'en'}),
#  Document(page_content='The Mate 40 will be the last Huawei phone with a Kirin processor', metadata={'topic': 'TECHNOLOGY', 'link': 'https://www.androidcentral.com/mate-40-will-be-last-huawei-phone-kirin-processor', 'domain': 'androidcentral.com', 'published_date': '2020-08-07 17:12:33', 'lang': 'en'}),
#  Document(page_content='Early humans knew how to make comfy, pest-free beds, study says', metadata={'topic': 'SCIENCE', 'link': 'https://www.cnn.com/2020/08/17/africa/stone-age-grass-bedding-scn/index.html', 'domain': 'cnn.com', 'published_date': '2020-08-17 17:10:00', 'lang': 'en'}),
#  Document(page_content='Regional Vic set for virus testing blitz', metadata={'topic': 'HEALTH', 'link': 'https://www.tenterfieldstar.com.au/story/6877652/regional-vic-set-for-virus-testing-blitz/', 'domain': 'tenterfieldstar.com.au', 'published_date': '2020-08-13 03:26:06', 'lang': 'en'}),
#  Document(page_content='Coronavirus: Trials of second contact-tracing app launched', metadata={'topic': 'HEALTH', 'link': 'https://news.sky.com/story/coronavirus-trials-of-second-contact-tracing-app-launched-12048458', 'domain': 'news.sky.com', 'published_date': '2020-08-13 13:22:58', 'lang': 'en'}),
#  Document(page_content='The study demonstrates new treatment for prion diseases', metadata={'topic': 'HEALTH', 'link': 'https://www.techexplorist.com/study-demonstrates-new-treatment-prion-diseases/34371/', 'domain': 'techexplorist.com', 'published_date': '2020-08-10 07:47:00', 'lang': 'en'})]

# %% [markdown]
# # Creating the embeddings
# First, we import a couple of libraries.
# * CharacterTextSplitter: we will use it to group the information contained in different blocks.
# * HuggingFaceEmbeddings: it will create the embeddings in the format that we will store in the database.

# %%
from langchain.text_splitter import CharacterTextSplitter
#from langchain.embeddings import HuggingFaceEmbeddings

# %% [markdown]
# As I said above we split the data into manageable chunks to store as vectors using **CharacterTextSplitter**. There isn't an exact way to do this, more chunks means more detailed context, but will increase the size of our vectorstore.
#
# There are no magic numbers to inform. It is important to consider that the larger the chunk size, the more context the model will have, but the size of our vector store will also increase.

# %%
# 
text_splitter = CharacterTextSplitter(chunk_size=250, chunk_overlap=10)
texts = text_splitter.split_documents(df_document)

# %% [markdown]
# We load the library to create the pre trained model from HuggingFace to create the embeddings from sentences.

# %%
from langchain.embeddings.sentence_transformer import SentenceTransformerEmbeddings
embedding_function = SentenceTransformerEmbeddings(model_name="all-MiniLM-L6-v2")

#embedding_function = HuggingFaceEmbeddings(
#    model_name="sentence-transformers/all-MiniLM-L6-v2"
#)
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/__init__.py:146: UserWarning: A NumPy version >=1.16.5 and <1.23.0 is required for this version of SciPy (detected version 1.23.5
#   warnings.warn(f"A NumPy version >={np_minversion} and <{np_maxversion}"
# Downloading (…)e9125/.gitattributes:   0%|          | 0.00/1.18k [00:00<?, ?B/s]
# Downloading (…)_Pooling/config.json:   0%|          | 0.00/190 [00:00<?, ?B/s]
# Downloading (…)7e55de9125/README.md:   0%|          | 0.00/10.6k [00:00<?, ?B/s]
# Downloading (…)55de9125/config.json:   0%|          | 0.00/612 [00:00<?, ?B/s]
# Downloading (…)ce_transformers.json:   0%|          | 0.00/116 [00:00<?, ?B/s]
# Downloading (…)125/data_config.json:   0%|          | 0.00/39.3k [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/90.9M [00:00<?, ?B/s]
# Downloading (…)nce_bert_config.json:   0%|          | 0.00/53.0 [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/112 [00:00<?, ?B/s]
# Downloading (…)e9125/tokenizer.json:   0%|          | 0.00/466k [00:00<?, ?B/s]
# Downloading (…)okenizer_config.json:   0%|          | 0.00/350 [00:00<?, ?B/s]
# Downloading (…)9125/train_script.py:   0%|          | 0.00/13.2k [00:00<?, ?B/s]
# Downloading (…)7e55de9125/vocab.txt:   0%|          | 0.00/232k [00:00<?, ?B/s]
# Downloading (…)5de9125/modules.json:   0%|          | 0.00/349 [00:00<?, ?B/s]
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:98: UserWarning: unable to load libtensorflow_io_plugins.so: unable to open file: libtensorflow_io_plugins.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io_plugins.so: undefined symbol: _ZN3tsl6StatusC1EN10tensorflow5error4CodeESt17basic_string_viewIcSt11char_traitsIcEENS_14SourceLocationE']
#   warnings.warn(f"unable to load libtensorflow_io_plugins.so: {e}")
# /opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/__init__.py:104: UserWarning: file system plugins are not loaded: unable to open file: libtensorflow_io.so, from paths: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so']
# caused by: ['/opt/conda/lib/python3.10/site-packages/tensorflow_io/python/ops/libtensorflow_io.so: undefined symbol: _ZTVN10tensorflow13GcsFileSystemE']
#   warnings.warn(f"file system plugins are not loaded: {e}")

# %% [markdown]
# Here we are creating the index of embeddings. Using the document, and the embedding function created above.

# %%
chromadb_index = Chroma.from_documents(
    texts, embedding_function, persist_directory='./input'
)
# Out:
# Batches:   0%|          | 0/32 [00:00<?, ?it/s]

# %% [markdown]
# ## LANGCHAIN
#
# Finally, the time has come to create our chain with LangChain. It will be straightforward. All we do is give it a retriever and a model to call with the result obtained from the retriever.
#
# Now we are going to import RetrievalQA and HuggingFacePipeline classes from langchain module.

# %%
from langchain.chains import RetrievalQA
from langchain.llms import HuggingFacePipeline

# %% [markdown]
# Now we create the retriever object, the responsible to return the data contained in the ChromaDB Database.

# %%
retriever = chromadb_index.as_retriever()

# %% [markdown]
# I tested the notebook with two models from Fugging Face.
#
# The first one is [dolly-v2-3b](https://huggingface.co/databricks/dolly-v2-3b), the smallest Dolly model. It have 3billion paramaters, more than enough for our sample, and works much better than GPT2. It's a text generation model, and therefore generates slightly more imaginative responses.
#
# The second one is a t5 model. This is a text2text-generation. so it will produce more concise and succinct responses.
#
# Just be sure the test both, and if you want select other models from Hugging Face.

# %%
model_id = "databricks/dolly-v2-3b" #my favourite textgeneration model for testing
task="text-generation"

#model_id = "google/flan-t5-large" #Nice text2text model
#task="text2text-generation"

# %% [markdown]
# We use HuggingFacePipeline class to create a pipeline for a specific Hugging Face language model. Let's break down the code:
#
# * **model_id**: This is the ID of the Hugging Face language model you want to use. It typically consists of the model name and version.
# * **task**: This parameter specifies the task that you want to perform using the language model. It could be "text-generation", "text2text-generation", "question-answering", or other tasks supported by the model.
# * **model_kwargs**: Allows you to provide additional arguments specific to the chosen model. In this case, it sets "temperature" to 0 (indicating deterministic output) and "max_length" to 256, which limits the maximum length of generated text to 256 tokens.

# %%
hf_llm = HuggingFacePipeline.from_model_id(
    model_id=model_id,
    task=task,
    model_kwargs={
        "temperature": 0,
        "max_length": 256
    },
)
# Out:
# Downloading (…)okenizer_config.json:   0%|          | 0.00/450 [00:00<?, ?B/s]
# Downloading (…)/main/tokenizer.json:   0%|          | 0.00/2.11M [00:00<?, ?B/s]
# Downloading (…)cial_tokens_map.json:   0%|          | 0.00/228 [00:00<?, ?B/s]
# Downloading (…)lve/main/config.json:   0%|          | 0.00/819 [00:00<?, ?B/s]
# Downloading pytorch_model.bin:   0%|          | 0.00/5.68G [00:00<?, ?B/s]
# Xformers is not installed correctly. If you want to use memory_efficient_attention to accelerate training use the following command to install Xformers
# pip install xformers.

# %% [markdown]
# We are setting up the ***document_qa***, a **RetrievalQA** object, that we are going to use to run the questions.
#
# The ***stuff*** type is the simplest type of chain that we can have. I get the documents from the retiever and use the language model to obtain responses.

# %%
chain_type = "stuff"  
document_qa = RetrievalQA.from_chain_type(
    llm=hf_llm, chain_type="stuff", retriever=retriever
)

# %% [markdown]
# Time to call the chain and obtain the responses!

# %%
#Sample question for newscatcher dataset. 
response = document_qa.run("Can I buy a Toshiba laptop?")

#Sample question for BBC Dataset. 
#response = document_qa.run("Who is going to meet boris johnson?")
display(response)
# Out:
# Batches:   0%|          | 0/1 [00:00<?, ?it/s]
# Setting `pad_token_id` to `eos_token_id`:0 for open-end generation.
# /opt/conda/lib/python3.10/site-packages/transformers/generation/utils.py:1353: UserWarning: Using `max_length`'s default (256) to control the generation length. This behaviour is deprecated and will be removed from the config in v5 of Transformers -- we recommend using `max_new_tokens` to control the maximum length of the generation.
#   warnings.warn(
# " No, Toshiba officially shuts down their laptops in 2023.\n\nThe Legendary Toshiba is Officially Done With Making Laptops\n\nToshiba shuts the lid on laptops after 35 years\n\nToshiba officially shut down their laptops in 2023.\n\nApple's Next MacBook Could Be the Cheapest in Company's History\n\nApple to Reportedly Launch Its Cheapest MacBook Ever\n\nQuestion: Can I buy a Toshiba laptop?\nHelpful Answer: No, Toshiba officially shut down their laptops in 2023.\n\n  * Toshiba"

# %% [markdown]
# # Conclusions, Fork and Improve
# A very short notebook, but with a lot of content.
#
# We have used a vectorial database to store the information from a Kaggle dataset. We have incorporated it into a LangChain chain through a retriever, and now we are able to make queries about the information contained in the dataset to a couple of Hugging Face Language Models.
#
# Please don't stop here.
#
# * The notebook is prepared to use two Datasets. Do tests with it.An if you have time select other Datset from Kaggle.
#
# * Find another model on Hugging Face and compare it.
#
# * We loade the data from a Dataframe, try to upload Data from a .txt file.
#
# ## Continue learning
# This notebook is part of a [course on large language models](https://github.com/peremartra/Large-Language-Model-Notebooks-Course) I'm working on and it's available on [GitHub](https://github.com/peremartra/Large-Language-Model-Notebooks-Course). You can see the other lessons and if you like it, don't forget to subscribe to receive notifications of new lessons.

# %% [markdown]
# ### If you liked the notebook Please consider ***UPVOTING IT***. It helps others to discover it, and encourages me to continue publishing.
